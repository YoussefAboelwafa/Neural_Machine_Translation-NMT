# %% [markdown]
# ## Installing Packages
#
# Install PyTorch using pip. See [https://pytorch.org/](https://pytorch.org/) if you want to install it on your computer.
# In addition, we will also be needing [huggingface](https://huggingface.co/)'s `transformers` and `datasets` libraries, and [nltk](https://www.nltk.org/) to compute the BLEU score.

# %%
# # Pytorch is typically already installed in Google Colab (uncomment to install):
# # !pip install torch==1.8.0
# # or for GPU support:
# # !pip install torch==1.8.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install transformers==4.27.0
# !pip install datasets==2.10.0
# # NLTK is typically also already installed in Google Colab (uncomment to install):
# !pip install nltk==3.8.1

# %% [markdown]
# ## Download NMT data

# %% [markdown]
# We first download the data for NMT, which contains pairs of parallel sentences.

# %%
# !wget --quiet https://princeton-nlp.github.io/cos484/assignments/a4/resources.zip
# !unzip -qo resources.zip

# %% [markdown]
# ## Data preprocessing
#
# In this section we will write code to load and tokenize the data for NMT.
#
# The parallel data is provided as huggingface datasets, one for each split of `train`, `validation` and `test`. We load it via the `load_from_disk` method and inspect its features. If you'd like to know more about these dataset objects, have a look at [this tutorial](https://huggingface.co/docs/datasets/access).

# %%
from datasets import load_from_disk

raw_text_datasets = load_from_disk("file://resources/parallel_en_fr_corpus")

print("Summary of splits:", raw_text_datasets)
print("First training example:", raw_text_datasets["train"][0])
# Out:
# Summary of splits: DatasetDict({
#     train: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 8701
#     })
#     validation: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 485
#     })
#     test: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 486
#     })
# })
# First training example: {'text_en': 'i m tough .', 'text_fr': 'je suis dure .'}

# %% [markdown]
# You are also provided with two pre-trained tokenizers for the source and target languages respectively, which we can load with the hugginface transfomers library. [This tutorial](https://huggingface.co/docs/transformers/preprocessing#natural-language-processing) provides an introduction to using pre-trained tokenizers and the powerful `AutoTokenizer` class. The tokenizers are based on byte-pair encodings which break words into smaller units. This is aimed at reducing the sparsity of words, as subwords can be shared between different rare words. If you are interested in learning more, see the paper [Neural Machine Translation of Rare Words with Subword Units](https://www.aclweb.org/anthology/P16-1162.pdf).

# %%
from transformers import AutoTokenizer

source_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_fr")
target_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_en")

print("Vocab size of source language:", source_tokenizer.vocab_size)
print("Vocab size of target language:", target_tokenizer.vocab_size)

# As a demonstration, we will the following English sentence to tokens.
example_sentence = "we have an example"
tokenizer_output = target_tokenizer(example_sentence)
print("\n*** Example ***")
print("Example sentence:", example_sentence)
print("Tokenizer output:", tokenizer_output)

# We convert every token id to its associated string, but find the special character ▁ which indicates the beginning of a word.
# Note that very common words are represented by a single token, while others are split into subunits due to the small vocab size.
# Also note that †he tokenizer already adds special tokens to the beginning and end of the sentence.
decoded_sequence = [
    target_tokenizer.decode(token) for token in tokenizer_output["input_ids"]
]
print("Tokens:", decoded_sequence)

# By replacing the special character ▁ with whitespace, we can reconstruct a legibile sentence,
# which differs from the original example by special tokens, includings <unk> tokens, and minor whitespace differences.
reconstructed = "".join(decoded_sequence).replace("▁", " ")
print("Reconstructed sentence", reconstructed)
# Out:
# Vocab size of source language: 3200
# Vocab size of target language: 3200
#
# *** Example ***
# Example sentence: we have an example
# Tokenizer output: {'input_ids': [1, 64, 324, 103, 266, 1490, 92, 2], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}
# Tokens: ['<s>', '▁we', '▁have', '▁an', '▁ex', 'amp', 'le', '</s>']
# Reconstructed sentence <s> we have an example</s>

# %% [markdown]
# We now want to convert the entire dataset to token ids.
# Specifically, we want to use the tokenizers to create a dataset with
# features "encoder_input_ids" and "decoder_input_ids", which both have type `List[int]`
# and which will later be the inputs to our encoder-decoder model. We will implement this using the powerful `map` function. You can find its API reference [here](https://huggingface.co/docs/datasets/v2.10.0/en/package_reference/main_classes#datasets.Dataset.map).

# %%
from typing import Dict, List


def map_example(example: Dict[str, str]) -> Dict[str, List[int]]:
    # TODO: Tokenize the source and target text for an entry in the parallel dataset
    # and return a dictionary with the keys "encoder_input_ids" and "decoder_input_ids".
    # You can use `source_tokenizer` and `target_tokenizer`

    source_encoded = source_tokenizer(example["text_fr"])
    target_encoded = target_tokenizer(example["text_en"])

    return {
        "encoder_input_ids": source_encoded["input_ids"],
        "decoder_input_ids": target_encoded["input_ids"],
    }


# When mapped is applied to the DatasetDict object, it will apply `map` separately to each split.
tokenized_datasets = raw_text_datasets.map(map_example, batched=False)

# The `remove_columns` removes the existing text features from the new dataset, as they are no longer needed.
tokenized_datasets = tokenized_datasets.remove_columns(
    raw_text_datasets.column_names["train"]
)

# Sanity checks on the new dataset
assert set(tokenized_datasets.column_names["train"]) == {
    "decoder_input_ids",
    "encoder_input_ids",
}
assert len(tokenized_datasets["train"]) == len(raw_text_datasets["train"])
# Out:
# Map:   0%|          | 0/8701 [00:00<?, ? examples/s]
# Map:   0%|          | 0/485 [00:00<?, ? examples/s]
# Map:   0%|          | 0/486 [00:00<?, ? examples/s]

# %%
print(source_tokenizer.decode(tokenized_datasets["train"][0]["encoder_input_ids"]))
print(target_tokenizer.decode(tokenized_datasets["train"][0]["decoder_input_ids"]))
# Out:
# <s> ▁je ▁suis ▁dure ▁. </s>
# <s> ▁i ▁m ▁tough ▁. </s>

# %% [markdown]
# ## Transformer model for NMT

# %% [markdown]
# We will now implement a encoder-decoder transformer model.
# We already provide code for the Feedforward Layers and Transformer Blocks, but you will have to implement the MultiHeadAttention and Embedding layer from scratch, as well as registering all the layers in the final EncoderDecoderModel. Pay attention to doc-strings and typing information to understand the context and purpose of each missing code block!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import math
from typing import Optional, Dict, List, Tuple

# %%
class MultiHeadAttention(nn.Module):
    def __init__(
        self,
        hidden_size: int,
        num_attention_heads: int,
        is_causal_attention: bool = False,
        is_cross_attention: bool = False,
    ):
        """Defines a flexible multi-head attention layer.

        This layer should define parameters for the query, key and value projections, as well as the output projection,
        and implement the following steps:
        (1) Project the input vectors using query projection and key projection matrices.
        (2) Compute the head-wise attention scores scaled by 1/sqrt(head_dim)
        (3) Perform appropriate masking to the attention scores using key_padding_mask and optionally causal attention.
        (4) Normalize the head-wise attention scores using softmax.
        (5) Compute the value projections and then aggregate using the normalized attention scores.
        (6) Use the output projection to obtain the final output vectors.
        When is_cross_attention is True, the key and value projections are computed from the encoder outputs.
        Note that we do not use attention weight dropout in this implementation.

        Args:
            hidden_size: The dimensionality of the input vectors.
            num_attention_heads: The number of attention heads.
            is_causal_attention: Whether to use causal masking,
                    where tokens cannot attend to the future tokens on their right.
            is_cross_attention: Whether to use cross attention,
                    where we use different inputs for the key/value vs. query vectors.
        """
        super().__init__()
        assert (
            hidden_size % num_attention_heads == 0
        ), "The hidden size must be divisible by the number of attention heads."
        self.head_dim = (
            hidden_size // num_attention_heads
        )  # embedding dimension of query and key vectors per head

        # TODO Initialize the module and its parameters here.
        # This module should be able to handle both full self-attention, causal masked self-attention and cross-attention.
        # IMPORTANT: You are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!

        self.hidden_size = hidden_size  # embedding dimension of input vectors
        self.num_attention_heads = num_attention_heads
        self.is_causal_attention = is_causal_attention
        self.is_cross_attention = is_cross_attention

        self.wq = nn.Linear(hidden_size, hidden_size)
        self.wk = nn.Linear(hidden_size, hidden_size)
        self.wv = nn.Linear(hidden_size, hidden_size)
        self.wo = nn.Linear(
            hidden_size, hidden_size
        )  # input size = output size = hidden_size

    def causal_attention_mask(
        self, sequence_length: int, device: Optional[torch.device] = None
    ) -> torch.FloatTensor:
        """Return a Float tensor that can be added to the (un-normalized) attention scores for causal masking.

        Args:
            sequence_length: width and height of the attention mask tensor.
            device: which torch device the resulting tensor should be on (important if you use GPU).

        Returns:
            A Float tensor of shape (1, 1, sequence_length, sequence_length) on device `device`,
            where the entries above the diagonal contain large negative values,
            which means that a query at position i can't attend to a key at position j>i.
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops.
        #
        # Hint 1: You can pick an arbitrary large value (e.g., -10^{6}), but note that
        #         using `float("-inf")` might lead to numerical issues and 'nan' values during training.
        #
        # Hint 2: Useful pytorch functions for this are `torch.arange` or `torch.triu`.
        #
        # Hint 3: You can move the tensor you create to a device by calling `tensor.to(device)`
        #
        # You should use this function in `forward` and use the returned tensor to implement causal masking
        # by adding it to the un-normalized attention scores of shape (batch_size, num_heads, sequence_length, sequence_length),
        # as torch will handle broadcasting and expand the first two dimensions to batch size and num_heads.
        #
        # You will the masking tensor to be on the same device as the attention scores's device,
        # which you can via the attribute `tensor.device`.

        return torch.triu(
            torch.full(
                (1, 1, sequence_length, sequence_length), fill_value=-1e6, device=device
            ),
            diagonal=1,
        )  # upper triangular matrix

    def forward(
        self,
        hidden_states: torch.FloatTensor,
        key_padding_mask: torch.BoolTensor,
        encoder_outputs: Optional[torch.FloatTensor] = None,
    ) -> Tuple[torch.FloatTensor, torch.FloatTensor]:
        """Computes scaled dot-product attention and returns the output of the attention layer.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the input vectors to the layer.
            key_padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
                    In the case of cross-attention, the tensor has shape (batch_size, encoder_sequence_length).
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size).
                    The output vectors of the encoder and only passed if the layer performs cross-attention.

        Returns:
            A (layer_output, attention_weights) where layer_output is a tensor of shape (batch_size, sequence_length, hidden_size)
            and attention_weights are the normalized attention scores in the form of
            a tensor of shape (batch_size, num_attention_heads, number_of_query_tokens, number_of_key_tokens).
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops. Furthermore,
        #            you are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        #
        # Hint 1: Use `torch.reshape` to add a new axis for the attention head,
        #         which will allow you to process all attention heads in parallel.
        #
        # Hint 2: You can use `torch.transpose` to swap the order of two axes,
        #         As the attention head dimension should be next to the batch size,
        #         see the shape of the output attention weights.
        #
        # Hint 3: `torch.bmm(matrix1, matrix2)` is useful for computing batched matrix multiplications
        #         If matrix1 has shape (B, M, N) and matrix2 has shape (B, N, P),
        #         it performs `B` matrix multiplications and outputs a tensor of shape (B, M, P).
        #         Alternatively, `torch.einsum` should be very useful.
        #         (We really encourage you to check out the documentation of `torch.einsum`,
        #         it can really make your life easier here.)

        query = self.wq(hidden_states)  # take the query from the hidden states
        key = (
            self.wk(hidden_states)
            if not self.is_cross_attention
            else self.wk(encoder_outputs)
        )  # take the key from the hidden states if not cross attention, otherwise take it from the encoder outputs
        value = (
            self.wv(hidden_states)
            if not self.is_cross_attention
            else self.wv(encoder_outputs)
        )  # take the value from the hidden states if not cross attention, otherwise take it from the encoder outputs

        # (b, n, hidden_size) --> (b, n, num_heads, head_dim)
        query = query.view(
            query.shape[0], query.shape[1], self.num_attention_heads, self.head_dim
        )
        key = key.view(
            key.shape[0], key.shape[1], self.num_attention_heads, self.head_dim
        )
        value = value.view(
            value.shape[0], value.shape[1], self.num_attention_heads, self.head_dim
        )

        # (b, n, num_heads, head_dim) --> (b, num_heads, n, head_dim)
        query = query.transpose(1, 2)
        key = key.transpose(1, 2)
        value = value.transpose(1, 2)

        # (b, num_heads, q, head_dim) x (b, num_heads, k, head_dim) --> (b, num_heads, q, k)
        scores = torch.einsum("bhqd,bhkd->bhqk", query, key) / math.sqrt(self.head_dim)

        # q = k if not cross_attention
        # q != k if cross_attention

        # apply causal mask if true
        if self.is_causal_attention:
            # hidden_states :(b, n, hidden_size)
            causal_mask = self.causal_attention_mask(
                hidden_states.size(1), device=hidden_states.device
            )
            scores.masked_fill_(causal_mask == -1e6, -1e9)

        # (b, n) ==> (b * 1 * 1 * n)
        if key_padding_mask is not None:
            scores = scores.masked_fill(
                key_padding_mask.unsqueeze(1).unsqueeze(2), -1e9
            )

        attention_weights = torch.softmax(scores, dim=-1)  # socres: (b,num_heads,n,n)

        attention_output = torch.matmul(
            attention_weights, value
        )  # attention_output: (b, h , n, head_dim)

        # concatenate the heads
        # hidden_states :(b, n, hidden_size)
        # (b, num_heads, n, head_dim) --> (b, n, num_heads, head_dim) --> (b, n, hidden_size)
        attention_output = (
            attention_output.transpose(1, 2)
            .contiguous()
            .view(hidden_states.size(0), -1, hidden_states.size(-1))
        )

        output = self.wo(attention_output)

        return output, attention_weights

# %% [markdown]
# Before we move on to the other modules, you should implement a sanity check for your attention implementation:
#
# 1. We check the dimensions of the output of the layer and
# 2. We plot the attention weights to some toy embedding inputs.
#    We assume that the last token in the encoder and the last two tokens in the decoder are pad tokens.

# %%
embed_dim = 8
num_heads = 2
batch_size = 1
encoder_seq_length = 5
decoder_seq_length = 7

encoder_outputs = torch.randn(batch_size, encoder_seq_length, embed_dim)
decoder_inputs = torch.randn(batch_size, decoder_seq_length, embed_dim)

encoder_padding_mask = torch.zeros(batch_size, encoder_seq_length, dtype=torch.bool)
encoder_padding_mask[:, -1] = True  # The last encoder token is a padding tokens

decoder_padding_mask = torch.zeros(batch_size, decoder_seq_length, dtype=torch.bool)
decoder_padding_mask[:, -2:] = True  # The last two decoder tokens are padding token


cross_attention = MultiHeadAttention(embed_dim, num_heads, is_cross_attention=True)
causal_attention = MultiHeadAttention(embed_dim, num_heads, is_causal_attention=True)

cross_attention_out, cross_attention_weights = cross_attention(
    decoder_inputs, encoder_padding_mask, encoder_outputs
)
causal_attention_out, causal_attention_weights = causal_attention(
    decoder_inputs, decoder_padding_mask
)

# Make sure your outputs have the right hapes
assert cross_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert cross_attention_weights.shape == (
    batch_size,
    num_heads,
    decoder_seq_length,
    encoder_seq_length,
)
assert causal_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert causal_attention_weights.shape == (
    batch_size,
    num_heads,
    decoder_seq_length,
    decoder_seq_length,
)

# Check that the attention weights are normalized
assert torch.isclose(cross_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()
assert torch.isclose(causal_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()

# Check if the attention masking works
assert torch.isclose(cross_attention_weights[:, :, :, -1], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:, :, :, -2:], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:, :, 2, 3:], torch.tensor(0.0)).all()


import matplotlib.pyplot as plt
import seaborn as sns


def plot_attention_matrix(attention_matrix, title):
    """Creates a new figure and plots the normalized attention weights as a heatmap.

    This should provide a colorbar for the scale of the heatmap and label the axes "query token position" and "key token position".
    Args:
        attention_matrix: A numpy array of shape (number_of_query_tokens, number_of_key_tokens)
        title: The title of the plot.
    """
    # TODO Implement this function

    plt.figure(figsize=(8, 6))
    plt.imshow(attention_matrix, aspect="auto", cmap="viridis")
    plt.colorbar()
    plt.title(title)
    plt.xlabel("Key token position")
    plt.ylabel("Query token position")
    plt.show()


plot_attention_matrix(
    cross_attention_weights[0, 0].detach().numpy(), "cross-attention, head 1"
)
plot_attention_matrix(
    cross_attention_weights[0, 1].detach().numpy(), "cross-attention, head 2"
)
plot_attention_matrix(
    causal_attention_weights[0, 0].detach().numpy(), "causal self-attention, head 1"
)
plot_attention_matrix(
    causal_attention_weights[0, 1].detach().numpy(), "causal self-attention, head 2"
)

# %%
class TransformerEmbeddings(nn.Module):
    def __init__(self, vocab_size: int, hidden_size: int, max_sequence_length: int):
        """Defines the embedding layer with learnt positional embeddings.

        This layer defines both the token embeddings and positional embeddings,
        which are added together to form the final embedding.

        Args:
            vocab_size: The size of the vocabulary,
                    used to define the size of the token embedding table.
            hidden_size: The dimensionality of the embedding space for both token embeddings and positional embeddings.
            max_sequence_length: The maximum sequence length of the input sequences,
                    used to define the size of the position embedding table.

        Note that this implementation does not use dropout on the embeddings
        and uses learnt positional embeddings instead of sinusoidal embeddings.
        """
        super().__init__()

        # TODO Initialize the module and its parameters here.
        # You should use `nn.Embedding` for both token embeddings and positional embeddings

        self.vocab_size = vocab_size
        self.hidden_size = hidden_size
        self.max_sequence_length = max_sequence_length

        self.embeddings = nn.Embedding(vocab_size, hidden_size)
        self.positional_embeddings = nn.Embedding(max_sequence_length, hidden_size)

    def compute_logits(self, decoder_output: torch.FloatTensor) -> torch.FloatTensor:
        """Computes the logits for the next token prediction given the decoder output.

        Args:
            decoder_output: Tensor of shape (batch_size, sequence_length, hidden_size) - the output of the decoder.

        Returns:
            Tensor of shape (batch_size, sequence_length, vocab_size) containing the logits for the next token prediction.
        """

        # TODO Implement this function
        # Hint: you can access the weight parameter matrix via .weight of an nn.Embedding module:
        # Example:
        # ```embeddings = nn.Embedding(num_embeddings, embedding_dim)
        # assert list(embeddings.weight.shape) == [num_embeddings, embedding_dim]```
        # torch.matmul or F.linear may also be useful here.
        return torch.matmul(decoder_output, self.embeddings.weight.t())

    def forward(self, input_ids: torch.LongTensor) -> torch.FloatTensor:
        """Computes the embeddings for the input tokens.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing
                    the sum of token embeddings and position embeddings for the input tokens.
        """

        # TODO Implement the forward pass of the embedding layer.
        # IMPORTANT: For full credit, you should not use python loops!
        emb = self.embeddings(input_ids)
        pos = self.positional_embeddings(
            torch.arange(self.max_sequence_length, device=input_ids.device)
        ).unsqueeze(0)

        pos = pos.expand(input_ids.size(0), -1, -1)[:, : input_ids.size(1), :]
        return emb + pos

# %% [markdown]
# ### Transformer Embedding Sanity Check

# %%
batch_size = 2
sequence_length = 3
vocab_size = 10
hidden_size = 8

te = TransformerEmbeddings(vocab_size, hidden_size, sequence_length)
input_ids = torch.randint(0, vocab_size, (batch_size, sequence_length))
result = te(input_ids)
result.shape
# Out:
# torch.Size([2, 3, 8])

# %%
class TransformerBlock(nn.Module):
    def __init__(
        self,
        hidden_size: int,
        intermediate_size: int,
        num_attention_heads: int,
        hidden_dropout_prob: float,
        is_decoder: bool = False,
    ):
        """Defines a single Transformer block, which can be either for the encoder or the decoder.

        Args:
            hidden_size: The dimensionality of the input and output vectors of this layer.
            intermediate_size: The intermediate size of the feedforward layers.
            num_attention_heads: The number of attention heads.
            hidden_dropout_prob: The dropout probability for the hidden states.
            is_decoder: Whether this block is part of the decoder.
        """
        super().__init__()

        self.is_decoder = is_decoder
        self.self_attention = MultiHeadAttention(
            hidden_size, num_attention_heads, is_causal_attention=is_decoder
        )
        self.self_attention_layer_norm = nn.LayerNorm(hidden_size)

        if is_decoder:
            self.cross_attention = MultiHeadAttention(
                hidden_size, num_attention_heads, is_cross_attention=True
            )
            self.cross_attention_layer_norm = nn.LayerNorm(hidden_size)

        self.feedforward = nn.Sequential(
            nn.Linear(hidden_size, intermediate_size),
            nn.ReLU(),
            nn.Linear(intermediate_size, hidden_size),
            nn.Dropout(hidden_dropout_prob),
        )
        self.feedforward_layer_norm = nn.LayerNorm(hidden_size)

    def forward(
        self,
        hidden_states: torch.FloatTensor,
        padding_mask: torch.BoolTensor,
        encoder_outputs: Optional[torch.FloatTensor] = None,
        encoder_padding_mask: Optional[torch.BoolTensor] = None,
    ) -> torch.FloatTensor:
        """Defines a single Transformer block, either for the encoder or the decoder.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the outputs from the previous layer.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size),
                    which are the output vectors of the encoder. This argument is only used by decoder blocks.
            encoder_padding_mask: Optional tensor of shape (batch_size, encoder_sequence_length) indicating
                    which encoder tokens are padding tokens. This argument is only used in decoder blocks.
                    A `True` entry means that this token should be ignored for the purpose of attention.

        """
        hidden_states = (
            self.self_attention(hidden_states, padding_mask)[0] + hidden_states
        )
        hidden_states = self.self_attention_layer_norm(hidden_states)

        if self.is_decoder:
            hidden_states = (
                self.cross_attention(
                    hidden_states, encoder_padding_mask, encoder_outputs
                )[0]
                + hidden_states
            )
            hidden_states = self.cross_attention_layer_norm(hidden_states)

        hidden_states = self.feedforward(hidden_states) + hidden_states
        hidden_states = self.feedforward_layer_norm(hidden_states)
        return hidden_states

# %%
class EncoderDecoderModel(nn.Module):
    def __init__(
        self,
        source_vocab_size: int,
        target_vocab_size: int,
        hidden_size: int,
        intermediate_size: int,
        num_attention_heads: int,
        num_encoder_layers: int,
        num_decoder_layers: int,
        max_sequence_length: int,
        hidden_dropout_prob: float,
    ):
        """A encoder-decoder transformer model which can be used for NMT.

        Args:
            source_vocab_size: The size of the source vocabulary.
            target_vocab_size: The size of the target vocabulary.
            hidden_size: The dimensionality of all input and output embeddings.
            intermediate_size: The intermediate size in the feedforward layers.
            num_attention_heads: The number of attention heads in each multi-head attention modules.
            num_encoder_layers: The number of transformer blocks in the encoder.
            num_decoder_layers: The number of transformer blocks in the decoder.
            max_sequence_length: The maximum sequence length that this model can handle.
            hidden_dropout_prob: The dropout probability in the hidden state in each block.
        """

        super().__init__()
        # TODO Register the input embedding modules and the encoder and decoder blocks.
        # You should use the TransformerBlock and TransformerEmbeddings sub-modules.
        #
        # Hint: Check out `nn.ModuleList` to register a variable number of sub-modules.

        self.encoder_embeddings = TransformerEmbeddings(
            source_vocab_size, hidden_size, max_sequence_length
        )
        self.decoder_embeddings = TransformerEmbeddings(
            target_vocab_size, hidden_size, max_sequence_length
        )

        self.encoder_blocks = nn.ModuleList(
            [
                TransformerBlock(
                    hidden_size,
                    intermediate_size,
                    num_attention_heads,
                    hidden_dropout_prob,
                )
                for _ in range(num_encoder_layers)
            ]
        )

        self.decoder_blocks = nn.ModuleList(
            [
                TransformerBlock(
                    hidden_size,
                    intermediate_size,
                    num_attention_heads,
                    hidden_dropout_prob,
                    is_decoder=True,
                )
                for _ in range(num_decoder_layers)
            ]
        )

        self.output = nn.Linear(hidden_size, target_vocab_size)

    def forward_encoder(
        self, input_ids: torch.LongTensor, padding_mask: torch.BoolTensor
    ) -> torch.FloatTensor:
        """Implement the forward pass of the encoder.

        Args:
            input_ids: tensor of shape (batch_size, sequence_length) containing the input token ids to the encoder.
            padding_mask: tensor of shape (batch_size, sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing the output embeddings of the encoder.
        """

        # TODO Implement this function

        source_embeddings = self.encoder_embeddings(input_ids)
        encoder_hidden_states = source_embeddings
        for encoder_block in self.encoder_blocks:
            encoder_hidden_states = encoder_block(encoder_hidden_states, padding_mask)

        return encoder_hidden_states

    def forward_decoder(
        self,
        input_ids: torch.LongTensor,
        padding_mask: torch.BoolTensor,
        encoder_outputs: torch.FloatTensor,
        encoder_padding_mask: torch.BoolTensor,
    ) -> torch.FloatTensor:
        """Implement the forward pass of the decoder.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids to the decoder.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which decoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.
            encoder_outputs: Tensor of shape (batch_size, encoder_sequence_length, hidden_size) containing the output embeddings of the encoder.
            encoder_padding_mask: Tensor of shape (batch_size, encoder_sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in cross-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, target_vocabulary_size)
            containing the logits for predicting the next token in the target sequence.
        """

        # TODO Implement this function

        target_embeddings = self.decoder_embeddings(input_ids)
        decoder_hidden_states = target_embeddings

        for decoder_block in self.decoder_blocks:
            decoder_hidden_states = decoder_block(
                decoder_hidden_states,
                padding_mask,
                encoder_outputs,
                encoder_padding_mask,
            )

        logits = self.decoder_embeddings.compute_logits(decoder_hidden_states)
        return logits

    def forward(
        self,
        encoder_input_ids,
        encoder_padding_mask,
        decoder_input_ids,
        decoder_padding_mask,
    ):
        encoder_outputs = self.forward_encoder(encoder_input_ids, encoder_padding_mask)
        logits = self.forward_decoder(
            decoder_input_ids,
            decoder_padding_mask,
            encoder_outputs,
            encoder_padding_mask,
        )

        return logits

# %% [markdown]
# ## Train the model
#
# In this section, we train the seq2seq model on the parallel tokenized corpus.
# Before you start training models, you should implement and test the model and its sub-modules, especially the attention.
#
# First, we implement a `collate` function, which takes a list of examples from the dataset and forms a batch,
# consisting of padded encoder and decoder input ids, as well as encoder and decoder padding masks.

# %%
def collate_fn(examples: List[Dict[str, List[int]]]) -> Dict[str, torch.Tensor]:
    """Collates a list of variable length sequences from the dataset into a batch of pytorch tensors with padding."""

    encoder_sequence_length = max(
        len(example["encoder_input_ids"]) for example in examples
    )
    decoder_sequence_length = max(
        len(example["decoder_input_ids"]) for example in examples
    )
    batch_size = len(examples)

    encoder_input_ids = torch.full(
        (batch_size, encoder_sequence_length),
        fill_value=source_tokenizer.pad_token_id,
        dtype=torch.int64,
    )
    encoder_padding_mask = torch.ones(
        (batch_size, encoder_sequence_length), dtype=torch.bool
    )

    decoder_input_ids = torch.full(
        (batch_size, decoder_sequence_length),
        fill_value=target_tokenizer.pad_token_id,
        dtype=torch.int64,
    )
    decoder_padding_mask = torch.ones(
        (batch_size, decoder_sequence_length), dtype=torch.bool
    )

    for i, example in enumerate(examples):
        encoder_input_ids[i, : len(example["encoder_input_ids"])] = torch.tensor(
            example["encoder_input_ids"]
        )
        encoder_padding_mask[i, : len(example["encoder_input_ids"])] = False

        decoder_input_ids[i, : len(example["decoder_input_ids"])] = torch.tensor(
            example["decoder_input_ids"]
        )
        decoder_padding_mask[i, : len(example["decoder_input_ids"])] = False

    return {
        "encoder_input_ids": encoder_input_ids,
        "encoder_padding_mask": encoder_padding_mask,
        "decoder_input_ids": decoder_input_ids,
        "decoder_padding_mask": decoder_padding_mask,
    }

# %% [markdown]
# Next, we provide a simple training loop.

# %%
import time
import math


def compute_loss_per_token(model, batch):
    logits = model(**batch)

    valid_label_mask = ~(batch["decoder_padding_mask"][:, 1:])
    labels = batch["decoder_input_ids"][:, 1:][valid_label_mask]
    logits = logits[:, :-1][valid_label_mask]

    return F.cross_entropy(logits, labels, reduction="none")


def evaluate_perplexity(model, dataset, batch_size=32, device="cpu"):
    model.eval()

    dev_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn
    )

    num_tokens = loss_sum = 0

    # no_grad() signals backend to throw away all gradients
    with torch.no_grad():
        for batch in dev_loader:
            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            token_losses = compute_loss_per_token(model, batch)

            loss_sum += token_losses.sum()
            num_tokens += token_losses.numel()

        dev_ppl = (loss_sum / num_tokens).exp().cpu().item()
    return dev_ppl


def train(
    model,
    training_dataset,
    validation_dataset,
    batch_size=32,
    lr=1e-3,
    max_epoch=10,
    log_every=10,
    valid_niter=100,
    model_path="model.pt",
):
    model.train()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Use device: %s" % device)

    model = model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    epoch = global_step = loss_sum = num_tokens = num_examples = 0
    best_valid_perplexity = float("inf")
    train_time = begin_time = time.time()
    print("Beginning maximum likelihood training")

    while True:
        train_loader = torch.utils.data.DataLoader(
            training_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn
        )
        epoch += 1
        batches_per_epoch = len(train_loader)
        for i, batch in enumerate(train_loader):
            global_step += 1

            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            optimizer.zero_grad()

            token_losses = compute_loss_per_token(model, batch)
            total_loss = token_losses.sum()

            loss = total_loss / batch_size
            loss.backward()

            optimizer.step()

            loss_sum += total_loss.cpu().item()
            num_tokens += token_losses.numel()
            num_examples += batch_size

            if global_step % log_every == 0:
                average_loss = loss_sum / num_examples
                average_ppl = math.exp(loss_sum / num_tokens)
                print(
                    f"epoch {epoch} ({i}/{batches_per_epoch}) | step {global_step} | "
                    f"avg_nll={average_loss:.2f} avg_ppl={average_ppl:.2f} "
                    f"speed={num_tokens / (time.time() - train_time):.2f} words/sec "
                    f"time_elapsed={time.time() - begin_time:.2f} sec"
                )

                train_time = time.time()
                loss_sum = num_tokens = num_examples = 0.0

            if global_step % valid_niter == 0:
                print("Begin validation ...")
                dev_perplexity = evaluate_perplexity(
                    model, validation_dataset, batch_size=batch_size, device=device
                )

                print(f"validation: step {global_step} | dev_ppl={dev_perplexity}")

                if dev_perplexity < best_valid_perplexity:
                    best_valid_perplexity = dev_perplexity
                    print(
                        f"epoch {epoch} step {global_step}: save currently the best model to '{model_path}'"
                    )
                    torch.save(model.state_dict(), model_path)
                    torch.save(optimizer.state_dict(), model_path + ".optim")
                model.train()

        if epoch == max_epoch:
            print("Reached maximum number of epochs")
            break

# %% [markdown]
# Let's train a relatively small model architecture for 15 epochs.
# With a reasonable implementation, this should take about 16 minutes on CPU / 3 minutes on GPU and we should achieve a validation perplexity of below 10!

# %%
# Set a random seed, so you obtain the same output model if you run this cell again.
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

model = EncoderDecoderModel(
    source_vocab_size=source_tokenizer.vocab_size,
    target_vocab_size=target_tokenizer.vocab_size,
    hidden_size=32,
    intermediate_size=32 * 4,
    num_attention_heads=4,
    num_encoder_layers=3,
    num_decoder_layers=3,
    max_sequence_length=32,
    hidden_dropout_prob=0.1,
)

print("Model architecture:", model)
print(
    "Total number of trainable model parameters:",
    sum(p.numel() for p in model.parameters() if p.requires_grad),
)

train(
    model,
    tokenized_datasets["train"],
    tokenized_datasets["validation"],
    max_epoch=15,
    model_path="model.pt",
)
# Out:
# Model architecture: EncoderDecoderModel(
#   (encoder_embeddings): TransformerEmbeddings(
#     (embeddings): Embedding(3200, 32)
#     (positional_embeddings): Embedding(32, 32)
#   )
#   (decoder_embeddings): TransformerEmbeddings(
#     (embeddings): Embedding(3200, 32)
#     (positional_embeddings): Embedding(32, 32)
#   )
#   (encoder_blocks): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (wq): Linear(in_features=32, out_features=32, bias=True)
#         (wk): Linear(in_features=32, out_features=32, bias=True)
#         (wv): Linear(in_features=32, out_features=32, bias=True)
#         (wo): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (decoder_blocks): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (wq): Linear(in_features=32, out_features=32, bias=True)
#         (wk): Linear(in_features=32, out_features=32, bias=True)
#         (wv): Linear(in_features=32, out_features=32, bias=True)
#         (wo): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (cross_attention): MultiHeadAttention(
#         (wq): Linear(in_features=32, out_features=32, bias=True)
#         (wk): Linear(in_features=32, out_features=32, bias=True)
#         (wv): Linear(in_features=32, out_features=32, bias=True)
#         (wo): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (cross_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (output): Linear(in_features=32, out_features=3200, bias=True)
# )
# Total number of trainable model parameters: 401536
# Use device: cpu
# Beginning maximum likelihood training
# epoch 1 (9/272) | step 10 | avg_nll=110.58 avg_ppl=6719337.29 speed=5602.05 words/sec time_elapsed=0.40 sec
# epoch 1 (19/272) | step 20 | avg_nll=87.25 avg_ppl=159075.72 speed=5755.73 words/sec time_elapsed=0.81 sec
# epoch 1 (29/272) | step 30 | avg_nll=80.83 avg_ppl=64417.76 speed=5673.26 words/sec time_elapsed=1.22 sec
# epoch 1 (39/272) | step 40 | avg_nll=72.67 avg_ppl=23548.93 speed=5354.69 words/sec time_elapsed=1.65 sec
# epoch 1 (49/272) | step 50 | avg_nll=65.25 avg_ppl=8693.09 speed=5481.42 words/sec time_elapsed=2.07 sec
# epoch 1 (59/272) | step 60 | avg_nll=58.50 avg_ppl=3535.48 speed=5464.67 words/sec time_elapsed=2.49 sec
# epoch 1 (69/272) | step 70 | avg_nll=53.08 avg_ppl=1581.89 speed=5427.60 words/sec time_elapsed=2.91 sec
# epoch 1 (79/272) | step 80 | avg_nll=50.97 avg_ppl=1126.66 speed=5767.24 words/sec time_elapsed=3.32 sec
# epoch 1 (89/272) | step 90 | avg_nll=48.62 avg_ppl=778.20 speed=6009.49 words/sec time_elapsed=3.71 sec
# epoch 1 (99/272) | step 100 | avg_nll=45.08 avg_ppl=558.08 speed=6338.69 words/sec time_elapsed=4.07 sec
# Begin validation ...
# validation: step 100 | dev_ppl=394.02642822265625
# epoch 1 step 100: save currently the best model to 'model.pt'
# epoch 1 (109/272) | step 110 | avg_nll=43.17 avg_ppl=411.15 speed=4054.27 words/sec time_elapsed=4.63 sec
# epoch 1 (119/272) | step 120 | avg_nll=41.76 avg_ppl=334.45 speed=5738.53 words/sec time_elapsed=5.03 sec
# epoch 1 (129/272) | step 130 | avg_nll=42.68 avg_ppl=328.58 speed=5712.01 words/sec time_elapsed=5.45 sec
# epoch 1 (139/272) | step 140 | avg_nll=40.09 avg_ppl=242.02 speed=4393.75 words/sec time_elapsed=5.98 sec
# epoch 1 (149/272) | step 150 | avg_nll=38.93 avg_ppl=209.30 speed=5575.18 words/sec time_elapsed=6.40 sec
# epoch 1 (159/272) | step 160 | avg_nll=37.82 avg_ppl=180.58 speed=5212.88 words/sec time_elapsed=6.84 sec
# epoch 1 (169/272) | step 170 | avg_nll=35.10 avg_ppl=132.01 speed=4798.93 words/sec time_elapsed=7.32 sec
# epoch 1 (179/272) | step 180 | avg_nll=37.15 avg_ppl=152.81 speed=4511.89 words/sec time_elapsed=7.85 sec
# epoch 1 (189/272) | step 190 | avg_nll=34.34 avg_ppl=114.49 speed=5601.87 words/sec time_elapsed=8.26 sec
# epoch 1 (199/272) | step 200 | avg_nll=33.51 avg_ppl=109.24 speed=5549.09 words/sec time_elapsed=8.67 sec
# Begin validation ...
# validation: step 200 | dev_ppl=86.82025909423828
# epoch 1 step 200: save currently the best model to 'model.pt'
# epoch 1 (209/272) | step 210 | avg_nll=31.90 avg_ppl=86.60 speed=3230.79 words/sec time_elapsed=9.38 sec
# epoch 1 (219/272) | step 220 | avg_nll=32.94 avg_ppl=93.34 speed=5033.98 words/sec time_elapsed=9.84 sec
# epoch 1 (229/272) | step 230 | avg_nll=33.09 avg_ppl=91.45 speed=5257.11 words/sec time_elapsed=10.29 sec
# epoch 1 (239/272) | step 240 | avg_nll=31.54 avg_ppl=74.69 speed=6038.46 words/sec time_elapsed=10.68 sec
# epoch 1 (249/272) | step 250 | avg_nll=32.14 avg_ppl=81.34 speed=5116.57 words/sec time_elapsed=11.13 sec
# epoch 1 (259/272) | step 260 | avg_nll=31.33 avg_ppl=74.74 speed=5281.57 words/sec time_elapsed=11.57 sec
# epoch 1 (269/272) | step 270 | avg_nll=29.89 avg_ppl=63.38 speed=5578.70 words/sec time_elapsed=11.99 sec
# epoch 2 (7/272) | step 280 | avg_nll=30.05 avg_ppl=63.48 speed=5683.45 words/sec time_elapsed=12.39 sec
# epoch 2 (17/272) | step 290 | avg_nll=28.61 avg_ppl=55.82 speed=4802.31 words/sec time_elapsed=12.87 sec
# epoch 2 (27/272) | step 300 | avg_nll=29.15 avg_ppl=52.74 speed=4515.10 words/sec time_elapsed=13.39 sec
# Begin validation ...
# validation: step 300 | dev_ppl=48.71064758300781
# epoch 2 step 300: save currently the best model to 'model.pt'
# epoch 2 (37/272) | step 310 | avg_nll=27.81 avg_ppl=49.27 speed=3534.92 words/sec time_elapsed=14.03 sec
# epoch 2 (47/272) | step 320 | avg_nll=28.37 avg_ppl=51.12 speed=5112.37 words/sec time_elapsed=14.49 sec
# epoch 2 (57/272) | step 330 | avg_nll=29.09 avg_ppl=50.68 speed=5318.58 words/sec time_elapsed=14.93 sec
# epoch 2 (67/272) | step 340 | avg_nll=27.77 avg_ppl=45.98 speed=5285.40 words/sec time_elapsed=15.37 sec
# epoch 2 (77/272) | step 350 | avg_nll=27.33 avg_ppl=42.26 speed=5205.63 words/sec time_elapsed=15.82 sec
# epoch 2 (87/272) | step 360 | avg_nll=27.67 avg_ppl=46.52 speed=5099.06 words/sec time_elapsed=16.27 sec
# epoch 2 (97/272) | step 370 | avg_nll=25.90 avg_ppl=37.76 speed=5341.96 words/sec time_elapsed=16.70 sec
# epoch 2 (107/272) | step 380 | avg_nll=26.30 avg_ppl=38.69 speed=5246.43 words/sec time_elapsed=17.14 sec
# epoch 2 (117/272) | step 390 | avg_nll=27.04 avg_ppl=40.12 speed=5754.45 words/sec time_elapsed=17.55 sec
# epoch 2 (127/272) | step 400 | avg_nll=26.94 avg_ppl=41.79 speed=5641.67 words/sec time_elapsed=17.95 sec
# Begin validation ...
# validation: step 400 | dev_ppl=35.237491607666016
# epoch 2 step 400: save currently the best model to 'model.pt'
# epoch 2 (137/272) | step 410 | avg_nll=27.70 avg_ppl=41.14 speed=4044.47 words/sec time_elapsed=18.54 sec
# epoch 2 (147/272) | step 420 | avg_nll=26.87 avg_ppl=38.68 speed=5983.96 words/sec time_elapsed=18.94 sec
# epoch 2 (157/272) | step 430 | avg_nll=25.43 avg_ppl=33.82 speed=5595.92 words/sec time_elapsed=19.35 sec
# epoch 2 (167/272) | step 440 | avg_nll=25.76 avg_ppl=34.43 speed=5692.88 words/sec time_elapsed=19.76 sec
# epoch 2 (177/272) | step 450 | avg_nll=24.99 avg_ppl=31.22 speed=6587.80 words/sec time_elapsed=20.11 sec
# epoch 2 (187/272) | step 460 | avg_nll=25.52 avg_ppl=33.66 speed=6688.75 words/sec time_elapsed=20.46 sec
# epoch 2 (197/272) | step 470 | avg_nll=25.63 avg_ppl=34.43 speed=6586.45 words/sec time_elapsed=20.81 sec
# epoch 2 (207/272) | step 480 | avg_nll=25.73 avg_ppl=34.14 speed=5930.48 words/sec time_elapsed=21.21 sec
# epoch 2 (217/272) | step 490 | avg_nll=24.19 avg_ppl=29.74 speed=5970.84 words/sec time_elapsed=21.59 sec
# epoch 2 (227/272) | step 500 | avg_nll=25.15 avg_ppl=32.40 speed=5767.71 words/sec time_elapsed=21.99 sec
# Begin validation ...
# validation: step 500 | dev_ppl=28.869531631469727
# epoch 2 step 500: save currently the best model to 'model.pt'
# epoch 2 (237/272) | step 510 | avg_nll=24.69 avg_ppl=28.54 speed=3929.47 words/sec time_elapsed=22.59 sec
# epoch 2 (247/272) | step 520 | avg_nll=23.95 avg_ppl=28.52 speed=5253.60 words/sec time_elapsed=23.02 sec
# epoch 2 (257/272) | step 530 | avg_nll=23.51 avg_ppl=26.90 speed=5422.35 words/sec time_elapsed=23.45 sec
# epoch 2 (267/272) | step 540 | avg_nll=24.34 avg_ppl=29.52 speed=5782.60 words/sec time_elapsed=23.84 sec
# epoch 3 (5/272) | step 550 | avg_nll=23.32 avg_ppl=25.97 speed=6534.21 words/sec time_elapsed=24.19 sec
# epoch 3 (15/272) | step 560 | avg_nll=23.76 avg_ppl=27.11 speed=6366.30 words/sec time_elapsed=24.56 sec
# epoch 3 (25/272) | step 570 | avg_nll=23.24 avg_ppl=24.23 speed=6351.55 words/sec time_elapsed=24.92 sec
# epoch 3 (35/272) | step 580 | avg_nll=23.60 avg_ppl=26.80 speed=4589.96 words/sec time_elapsed=25.42 sec
# epoch 3 (45/272) | step 590 | avg_nll=23.93 avg_ppl=26.95 speed=5415.30 words/sec time_elapsed=25.85 sec
# epoch 3 (55/272) | step 600 | avg_nll=23.39 avg_ppl=25.87 speed=5818.20 words/sec time_elapsed=26.25 sec
# Begin validation ...
# validation: step 600 | dev_ppl=24.263668060302734
# epoch 3 step 600: save currently the best model to 'model.pt'
# epoch 3 (65/272) | step 610 | avg_nll=22.04 avg_ppl=21.58 speed=4028.97 words/sec time_elapsed=26.82 sec
# epoch 3 (75/272) | step 620 | avg_nll=23.34 avg_ppl=24.65 speed=5510.36 words/sec time_elapsed=27.24 sec
# epoch 3 (85/272) | step 630 | avg_nll=23.59 avg_ppl=25.62 speed=5652.60 words/sec time_elapsed=27.65 sec
# epoch 3 (95/272) | step 640 | avg_nll=23.33 avg_ppl=24.44 speed=5799.85 words/sec time_elapsed=28.06 sec
# epoch 3 (105/272) | step 650 | avg_nll=23.25 avg_ppl=24.49 speed=5077.30 words/sec time_elapsed=28.51 sec
# epoch 3 (115/272) | step 660 | avg_nll=23.92 avg_ppl=25.65 speed=5381.98 words/sec time_elapsed=28.95 sec
# epoch 3 (125/272) | step 670 | avg_nll=22.17 avg_ppl=22.68 speed=6178.43 words/sec time_elapsed=29.32 sec
# epoch 3 (135/272) | step 680 | avg_nll=23.61 avg_ppl=24.74 speed=5720.15 words/sec time_elapsed=29.73 sec
# epoch 3 (145/272) | step 690 | avg_nll=21.79 avg_ppl=20.78 speed=5248.05 words/sec time_elapsed=30.17 sec
# epoch 3 (155/272) | step 700 | avg_nll=22.52 avg_ppl=22.08 speed=5029.16 words/sec time_elapsed=30.63 sec
# Begin validation ...
# validation: step 700 | dev_ppl=21.766691207885742
# epoch 3 step 700: save currently the best model to 'model.pt'
# epoch 3 (165/272) | step 710 | avg_nll=22.20 avg_ppl=21.61 speed=3638.01 words/sec time_elapsed=31.27 sec
# epoch 3 (175/272) | step 720 | avg_nll=23.07 avg_ppl=23.81 speed=5821.44 words/sec time_elapsed=31.67 sec
# epoch 3 (185/272) | step 730 | avg_nll=22.28 avg_ppl=22.28 speed=5678.40 words/sec time_elapsed=32.07 sec
# epoch 3 (195/272) | step 740 | avg_nll=22.54 avg_ppl=22.65 speed=5558.83 words/sec time_elapsed=32.49 sec
# epoch 3 (205/272) | step 750 | avg_nll=23.12 avg_ppl=23.74 speed=5312.88 words/sec time_elapsed=32.93 sec
# epoch 3 (215/272) | step 760 | avg_nll=22.59 avg_ppl=22.30 speed=5531.03 words/sec time_elapsed=33.35 sec
# epoch 3 (225/272) | step 770 | avg_nll=23.02 avg_ppl=23.61 speed=5573.32 words/sec time_elapsed=33.77 sec
# epoch 3 (235/272) | step 780 | avg_nll=23.00 avg_ppl=23.35 speed=5782.52 words/sec time_elapsed=34.17 sec
# epoch 3 (245/272) | step 790 | avg_nll=20.73 avg_ppl=17.82 speed=5295.48 words/sec time_elapsed=34.61 sec
# epoch 3 (255/272) | step 800 | avg_nll=21.68 avg_ppl=20.43 speed=5329.77 words/sec time_elapsed=35.04 sec
# Begin validation ...
# validation: step 800 | dev_ppl=19.944164276123047
# epoch 3 step 800: save currently the best model to 'model.pt'
# epoch 3 (265/272) | step 810 | avg_nll=21.74 avg_ppl=20.17 speed=2875.27 words/sec time_elapsed=35.85 sec
# epoch 4 (3/272) | step 820 | avg_nll=21.07 avg_ppl=19.69 speed=4606.10 words/sec time_elapsed=36.34 sec
# epoch 4 (13/272) | step 830 | avg_nll=21.46 avg_ppl=19.82 speed=5263.70 words/sec time_elapsed=36.77 sec
# epoch 4 (23/272) | step 840 | avg_nll=21.97 avg_ppl=20.18 speed=5879.32 words/sec time_elapsed=37.17 sec
# epoch 4 (33/272) | step 850 | avg_nll=22.51 avg_ppl=21.41 speed=5550.33 words/sec time_elapsed=37.60 sec
# epoch 4 (43/272) | step 860 | avg_nll=20.87 avg_ppl=18.50 speed=5473.63 words/sec time_elapsed=38.01 sec
# epoch 4 (53/272) | step 870 | avg_nll=21.51 avg_ppl=18.59 speed=5689.49 words/sec time_elapsed=38.43 sec
# epoch 4 (63/272) | step 880 | avg_nll=20.92 avg_ppl=18.31 speed=5587.19 words/sec time_elapsed=38.84 sec
# epoch 4 (73/272) | step 890 | avg_nll=21.62 avg_ppl=19.64 speed=5275.82 words/sec time_elapsed=39.28 sec
# epoch 4 (83/272) | step 900 | avg_nll=21.05 avg_ppl=18.75 speed=5595.80 words/sec time_elapsed=39.69 sec
# Begin validation ...
# validation: step 900 | dev_ppl=18.700008392333984
# epoch 4 step 900: save currently the best model to 'model.pt'
# epoch 4 (93/272) | step 910 | avg_nll=21.23 avg_ppl=17.94 speed=3553.70 words/sec time_elapsed=40.35 sec
# epoch 4 (103/272) | step 920 | avg_nll=20.82 avg_ppl=18.37 speed=5460.69 words/sec time_elapsed=40.77 sec
# epoch 4 (113/272) | step 930 | avg_nll=21.30 avg_ppl=18.63 speed=5774.04 words/sec time_elapsed=41.18 sec
# epoch 4 (123/272) | step 940 | avg_nll=20.07 avg_ppl=16.73 speed=6059.46 words/sec time_elapsed=41.55 sec
# epoch 4 (133/272) | step 950 | avg_nll=21.10 avg_ppl=18.03 speed=5209.45 words/sec time_elapsed=42.00 sec
# epoch 4 (143/272) | step 960 | avg_nll=19.30 avg_ppl=15.46 speed=5559.80 words/sec time_elapsed=42.41 sec
# epoch 4 (153/272) | step 970 | avg_nll=20.73 avg_ppl=16.94 speed=5594.41 words/sec time_elapsed=42.83 sec
# epoch 4 (163/272) | step 980 | avg_nll=21.17 avg_ppl=19.05 speed=5092.91 words/sec time_elapsed=43.28 sec
# epoch 4 (173/272) | step 990 | avg_nll=20.84 avg_ppl=17.86 speed=5043.67 words/sec time_elapsed=43.74 sec
# epoch 4 (183/272) | step 1000 | avg_nll=22.00 avg_ppl=20.94 speed=4810.62 words/sec time_elapsed=44.22 sec
# Begin validation ...
# validation: step 1000 | dev_ppl=17.61765480041504
# epoch 4 step 1000: save currently the best model to 'model.pt'
# epoch 4 (193/272) | step 1010 | avg_nll=21.48 avg_ppl=19.01 speed=3816.94 words/sec time_elapsed=44.83 sec
# epoch 4 (203/272) | step 1020 | avg_nll=20.91 avg_ppl=17.36 speed=6455.13 words/sec time_elapsed=45.19 sec
# epoch 4 (213/272) | step 1030 | avg_nll=20.86 avg_ppl=17.92 speed=6398.27 words/sec time_elapsed=45.55 sec
# epoch 4 (223/272) | step 1040 | avg_nll=21.07 avg_ppl=18.06 speed=6270.18 words/sec time_elapsed=45.92 sec
# epoch 4 (233/272) | step 1050 | avg_nll=21.24 avg_ppl=18.04 speed=6054.94 words/sec time_elapsed=46.31 sec
# epoch 4 (243/272) | step 1060 | avg_nll=20.56 avg_ppl=17.43 speed=5710.02 words/sec time_elapsed=46.72 sec
# epoch 4 (253/272) | step 1070 | avg_nll=20.33 avg_ppl=16.42 speed=5353.23 words/sec time_elapsed=47.15 sec
# epoch 4 (263/272) | step 1080 | avg_nll=19.45 avg_ppl=15.32 speed=6172.39 words/sec time_elapsed=47.52 sec
# epoch 5 (1/272) | step 1090 | avg_nll=20.39 avg_ppl=16.91 speed=6290.86 words/sec time_elapsed=47.89 sec
# epoch 5 (11/272) | step 1100 | avg_nll=20.41 avg_ppl=16.37 speed=5989.47 words/sec time_elapsed=48.28 sec
# Begin validation ...
# validation: step 1100 | dev_ppl=17.076759338378906
# epoch 5 step 1100: save currently the best model to 'model.pt'
# epoch 5 (21/272) | step 1110 | avg_nll=20.47 avg_ppl=16.32 speed=3306.40 words/sec time_elapsed=48.99 sec
# epoch 5 (31/272) | step 1120 | avg_nll=19.52 avg_ppl=15.34 speed=5446.49 words/sec time_elapsed=49.41 sec
# epoch 5 (41/272) | step 1130 | avg_nll=19.15 avg_ppl=14.47 speed=6105.20 words/sec time_elapsed=49.78 sec
# epoch 5 (51/272) | step 1140 | avg_nll=20.92 avg_ppl=16.72 speed=5501.44 words/sec time_elapsed=50.21 sec
# epoch 5 (61/272) | step 1150 | avg_nll=20.15 avg_ppl=15.86 speed=5355.15 words/sec time_elapsed=50.65 sec
# epoch 5 (71/272) | step 1160 | avg_nll=20.95 avg_ppl=17.95 speed=5542.49 words/sec time_elapsed=51.07 sec
# epoch 5 (81/272) | step 1170 | avg_nll=20.57 avg_ppl=16.27 speed=5003.68 words/sec time_elapsed=51.54 sec
# epoch 5 (91/272) | step 1180 | avg_nll=19.78 avg_ppl=15.59 speed=5541.48 words/sec time_elapsed=51.96 sec
# epoch 5 (101/272) | step 1190 | avg_nll=19.97 avg_ppl=16.12 speed=6026.16 words/sec time_elapsed=52.34 sec
# epoch 5 (111/272) | step 1200 | avg_nll=20.19 avg_ppl=15.85 speed=5563.79 words/sec time_elapsed=52.76 sec
# Begin validation ...
# validation: step 1200 | dev_ppl=15.606973648071289
# epoch 5 step 1200: save currently the best model to 'model.pt'
# epoch 5 (121/272) | step 1210 | avg_nll=19.67 avg_ppl=15.62 speed=4289.79 words/sec time_elapsed=53.29 sec
# epoch 5 (131/272) | step 1220 | avg_nll=19.91 avg_ppl=15.63 speed=6565.72 words/sec time_elapsed=53.65 sec
# epoch 5 (141/272) | step 1230 | avg_nll=19.62 avg_ppl=14.81 speed=5034.15 words/sec time_elapsed=54.11 sec
# epoch 5 (151/272) | step 1240 | avg_nll=18.81 avg_ppl=14.02 speed=5328.19 words/sec time_elapsed=54.54 sec
# epoch 5 (161/272) | step 1250 | avg_nll=18.17 avg_ppl=12.68 speed=5512.00 words/sec time_elapsed=54.95 sec
# epoch 5 (171/272) | step 1260 | avg_nll=18.50 avg_ppl=13.31 speed=5101.58 words/sec time_elapsed=55.40 sec
# epoch 5 (181/272) | step 1270 | avg_nll=19.68 avg_ppl=15.55 speed=6093.83 words/sec time_elapsed=55.78 sec
# epoch 5 (191/272) | step 1280 | avg_nll=19.23 avg_ppl=14.26 speed=5535.03 words/sec time_elapsed=56.20 sec
# epoch 5 (201/272) | step 1290 | avg_nll=19.87 avg_ppl=15.35 speed=5648.99 words/sec time_elapsed=56.61 sec
# epoch 5 (211/272) | step 1300 | avg_nll=19.87 avg_ppl=15.97 speed=6309.56 words/sec time_elapsed=56.97 sec
# Begin validation ...
# validation: step 1300 | dev_ppl=15.255422592163086
# epoch 5 step 1300: save currently the best model to 'model.pt'
# epoch 5 (221/272) | step 1310 | avg_nll=19.06 avg_ppl=14.27 speed=4014.61 words/sec time_elapsed=57.54 sec
# epoch 5 (231/272) | step 1320 | avg_nll=20.84 avg_ppl=16.83 speed=5834.65 words/sec time_elapsed=57.95 sec
# epoch 5 (241/272) | step 1330 | avg_nll=19.91 avg_ppl=15.16 speed=5802.55 words/sec time_elapsed=58.35 sec
# epoch 5 (251/272) | step 1340 | avg_nll=19.12 avg_ppl=14.21 speed=5772.85 words/sec time_elapsed=58.75 sec
# epoch 5 (261/272) | step 1350 | avg_nll=20.27 avg_ppl=16.21 speed=5251.58 words/sec time_elapsed=59.19 sec
# epoch 5 (271/272) | step 1360 | avg_nll=18.86 avg_ppl=14.02 speed=4992.23 words/sec time_elapsed=59.65 sec
# epoch 6 (9/272) | step 1370 | avg_nll=19.77 avg_ppl=14.62 speed=5614.71 words/sec time_elapsed=60.07 sec
# epoch 6 (19/272) | step 1380 | avg_nll=19.04 avg_ppl=13.34 speed=5565.07 words/sec time_elapsed=60.49 sec
# epoch 6 (29/272) | step 1390 | avg_nll=18.16 avg_ppl=12.67 speed=5578.07 words/sec time_elapsed=60.91 sec
# epoch 6 (39/272) | step 1400 | avg_nll=19.57 avg_ppl=14.34 speed=5924.38 words/sec time_elapsed=61.30 sec
# Begin validation ...
# validation: step 1400 | dev_ppl=14.478673934936523
# epoch 6 step 1400: save currently the best model to 'model.pt'
# epoch 6 (49/272) | step 1410 | avg_nll=20.01 avg_ppl=15.04 speed=4259.18 words/sec time_elapsed=61.86 sec
# epoch 6 (59/272) | step 1420 | avg_nll=19.67 avg_ppl=15.09 speed=6284.14 words/sec time_elapsed=62.23 sec
# epoch 6 (69/272) | step 1430 | avg_nll=17.84 avg_ppl=12.18 speed=5856.93 words/sec time_elapsed=62.62 sec
# epoch 6 (79/272) | step 1440 | avg_nll=18.42 avg_ppl=12.87 speed=6230.70 words/sec time_elapsed=62.99 sec
# epoch 6 (89/272) | step 1450 | avg_nll=19.38 avg_ppl=14.56 speed=5825.45 words/sec time_elapsed=63.38 sec
# epoch 6 (99/272) | step 1460 | avg_nll=17.74 avg_ppl=11.95 speed=5820.82 words/sec time_elapsed=63.78 sec
# epoch 6 (109/272) | step 1470 | avg_nll=19.71 avg_ppl=15.01 speed=6164.60 words/sec time_elapsed=64.15 sec
# epoch 6 (119/272) | step 1480 | avg_nll=18.46 avg_ppl=12.91 speed=5897.20 words/sec time_elapsed=64.55 sec
# epoch 6 (129/272) | step 1490 | avg_nll=19.18 avg_ppl=14.12 speed=6026.63 words/sec time_elapsed=64.93 sec
# epoch 6 (139/272) | step 1500 | avg_nll=19.10 avg_ppl=13.82 speed=6602.41 words/sec time_elapsed=65.28 sec
# Begin validation ...
# validation: step 1500 | dev_ppl=14.20543384552002
# epoch 6 step 1500: save currently the best model to 'model.pt'
# epoch 6 (149/272) | step 1510 | avg_nll=18.56 avg_ppl=13.22 speed=3921.69 words/sec time_elapsed=65.87 sec
# epoch 6 (159/272) | step 1520 | avg_nll=18.72 avg_ppl=13.16 speed=5804.86 words/sec time_elapsed=66.27 sec
# epoch 6 (169/272) | step 1530 | avg_nll=19.22 avg_ppl=14.06 speed=5729.11 words/sec time_elapsed=66.68 sec
# epoch 6 (179/272) | step 1540 | avg_nll=17.79 avg_ppl=11.95 speed=6195.05 words/sec time_elapsed=67.05 sec
# epoch 6 (189/272) | step 1550 | avg_nll=18.80 avg_ppl=13.45 speed=6265.31 words/sec time_elapsed=67.42 sec
# epoch 6 (199/272) | step 1560 | avg_nll=18.36 avg_ppl=12.67 speed=6271.00 words/sec time_elapsed=67.79 sec
# epoch 6 (209/272) | step 1570 | avg_nll=19.59 avg_ppl=14.71 speed=6068.69 words/sec time_elapsed=68.17 sec
# epoch 6 (219/272) | step 1580 | avg_nll=18.45 avg_ppl=12.72 speed=6027.11 words/sec time_elapsed=68.56 sec
# epoch 6 (229/272) | step 1590 | avg_nll=18.30 avg_ppl=13.08 speed=5798.22 words/sec time_elapsed=68.95 sec
# epoch 6 (239/272) | step 1600 | avg_nll=18.41 avg_ppl=12.69 speed=5723.77 words/sec time_elapsed=69.35 sec
# Begin validation ...
# validation: step 1600 | dev_ppl=13.200960159301758
# epoch 6 step 1600: save currently the best model to 'model.pt'
# epoch 6 (249/272) | step 1610 | avg_nll=18.30 avg_ppl=12.71 speed=4149.19 words/sec time_elapsed=69.91 sec
# epoch 6 (259/272) | step 1620 | avg_nll=18.51 avg_ppl=12.96 speed=6526.77 words/sec time_elapsed=70.26 sec
# epoch 6 (269/272) | step 1630 | avg_nll=18.33 avg_ppl=12.49 speed=6495.41 words/sec time_elapsed=70.62 sec
# epoch 7 (7/272) | step 1640 | avg_nll=18.30 avg_ppl=12.61 speed=6330.99 words/sec time_elapsed=70.99 sec
# epoch 7 (17/272) | step 1650 | avg_nll=16.88 avg_ppl=10.44 speed=4915.34 words/sec time_elapsed=71.45 sec
# epoch 7 (27/272) | step 1660 | avg_nll=17.75 avg_ppl=11.33 speed=4583.61 words/sec time_elapsed=71.96 sec
# epoch 7 (37/272) | step 1670 | avg_nll=18.17 avg_ppl=12.24 speed=5362.40 words/sec time_elapsed=72.40 sec
# epoch 7 (47/272) | step 1680 | avg_nll=18.80 avg_ppl=12.92 speed=5952.99 words/sec time_elapsed=72.79 sec
# epoch 7 (57/272) | step 1690 | avg_nll=17.22 avg_ppl=11.22 speed=6153.08 words/sec time_elapsed=73.16 sec
# epoch 7 (67/272) | step 1700 | avg_nll=19.40 avg_ppl=13.68 speed=5273.24 words/sec time_elapsed=73.61 sec
# Begin validation ...
# validation: step 1700 | dev_ppl=13.061911582946777
# epoch 7 step 1700: save currently the best model to 'model.pt'
# epoch 7 (77/272) | step 1710 | avg_nll=16.87 avg_ppl=10.80 speed=3985.93 words/sec time_elapsed=74.18 sec
# epoch 7 (87/272) | step 1720 | avg_nll=17.38 avg_ppl=11.11 speed=5284.83 words/sec time_elapsed=74.62 sec
# epoch 7 (97/272) | step 1730 | avg_nll=17.35 avg_ppl=10.74 speed=5982.71 words/sec time_elapsed=75.01 sec
# epoch 7 (107/272) | step 1740 | avg_nll=17.66 avg_ppl=11.93 speed=5552.62 words/sec time_elapsed=75.42 sec
# epoch 7 (117/272) | step 1750 | avg_nll=18.99 avg_ppl=13.34 speed=5699.67 words/sec time_elapsed=75.83 sec
# epoch 7 (127/272) | step 1760 | avg_nll=18.90 avg_ppl=13.16 speed=5570.94 words/sec time_elapsed=76.25 sec
# epoch 7 (137/272) | step 1770 | avg_nll=18.17 avg_ppl=12.29 speed=5604.84 words/sec time_elapsed=76.67 sec
# epoch 7 (147/272) | step 1780 | avg_nll=18.31 avg_ppl=12.30 speed=5832.91 words/sec time_elapsed=77.07 sec
# epoch 7 (157/272) | step 1790 | avg_nll=17.11 avg_ppl=10.88 speed=6066.67 words/sec time_elapsed=77.45 sec
# epoch 7 (167/272) | step 1800 | avg_nll=18.21 avg_ppl=12.41 speed=6225.07 words/sec time_elapsed=77.82 sec
# Begin validation ...
# validation: step 1800 | dev_ppl=12.773355484008789
# epoch 7 step 1800: save currently the best model to 'model.pt'
# epoch 7 (177/272) | step 1810 | avg_nll=17.50 avg_ppl=11.18 speed=4332.54 words/sec time_elapsed=78.35 sec
# epoch 7 (187/272) | step 1820 | avg_nll=17.73 avg_ppl=11.73 speed=5998.16 words/sec time_elapsed=78.74 sec
# epoch 7 (197/272) | step 1830 | avg_nll=18.70 avg_ppl=12.95 speed=6306.58 words/sec time_elapsed=79.11 sec
# epoch 7 (207/272) | step 1840 | avg_nll=18.19 avg_ppl=12.36 speed=6154.17 words/sec time_elapsed=79.48 sec
# epoch 7 (217/272) | step 1850 | avg_nll=17.49 avg_ppl=11.62 speed=5565.93 words/sec time_elapsed=79.89 sec
# epoch 7 (227/272) | step 1860 | avg_nll=18.69 avg_ppl=12.86 speed=6029.40 words/sec time_elapsed=80.28 sec
# epoch 7 (237/272) | step 1870 | avg_nll=16.97 avg_ppl=10.50 speed=5997.73 words/sec time_elapsed=80.67 sec
# epoch 7 (247/272) | step 1880 | avg_nll=17.18 avg_ppl=10.71 speed=6170.37 words/sec time_elapsed=81.04 sec
# epoch 7 (257/272) | step 1890 | avg_nll=16.85 avg_ppl=10.57 speed=6179.87 words/sec time_elapsed=81.41 sec
# epoch 7 (267/272) | step 1900 | avg_nll=17.38 avg_ppl=11.52 speed=6155.62 words/sec time_elapsed=81.78 sec
# Begin validation ...
# validation: step 1900 | dev_ppl=12.25201416015625
# epoch 7 step 1900: save currently the best model to 'model.pt'
# epoch 8 (5/272) | step 1910 | avg_nll=18.77 avg_ppl=12.61 speed=3984.22 words/sec time_elapsed=82.38 sec
# epoch 8 (15/272) | step 1920 | avg_nll=18.04 avg_ppl=11.35 speed=6260.41 words/sec time_elapsed=82.76 sec
# epoch 8 (25/272) | step 1930 | avg_nll=16.48 avg_ppl=10.07 speed=5517.80 words/sec time_elapsed=83.17 sec
# epoch 8 (35/272) | step 1940 | avg_nll=16.62 avg_ppl=10.18 speed=5380.57 words/sec time_elapsed=83.60 sec
# epoch 8 (45/272) | step 1950 | avg_nll=17.48 avg_ppl=10.84 speed=5955.24 words/sec time_elapsed=83.99 sec
# epoch 8 (55/272) | step 1960 | avg_nll=17.69 avg_ppl=11.24 speed=5129.70 words/sec time_elapsed=84.45 sec
# epoch 8 (65/272) | step 1970 | avg_nll=17.00 avg_ppl=10.44 speed=5216.36 words/sec time_elapsed=84.89 sec
# epoch 8 (75/272) | step 1980 | avg_nll=16.28 avg_ppl=9.61 speed=5601.31 words/sec time_elapsed=85.30 sec
# epoch 8 (85/272) | step 1990 | avg_nll=16.89 avg_ppl=10.21 speed=6021.98 words/sec time_elapsed=85.69 sec
# epoch 8 (95/272) | step 2000 | avg_nll=17.38 avg_ppl=11.31 speed=5422.79 words/sec time_elapsed=86.11 sec
# Begin validation ...
# validation: step 2000 | dev_ppl=12.215609550476074
# epoch 8 step 2000: save currently the best model to 'model.pt'
# epoch 8 (105/272) | step 2010 | avg_nll=17.11 avg_ppl=10.42 speed=3899.51 words/sec time_elapsed=86.71 sec
# epoch 8 (115/272) | step 2020 | avg_nll=16.51 avg_ppl=10.12 speed=5106.08 words/sec time_elapsed=87.16 sec
# epoch 8 (125/272) | step 2030 | avg_nll=17.12 avg_ppl=10.90 speed=5553.21 words/sec time_elapsed=87.57 sec
# epoch 8 (135/272) | step 2040 | avg_nll=16.34 avg_ppl=9.80 speed=5584.29 words/sec time_elapsed=87.98 sec
# epoch 8 (145/272) | step 2050 | avg_nll=17.93 avg_ppl=11.61 speed=5553.30 words/sec time_elapsed=88.40 sec
# epoch 8 (155/272) | step 2060 | avg_nll=16.67 avg_ppl=10.06 speed=5146.36 words/sec time_elapsed=88.85 sec
# epoch 8 (165/272) | step 2070 | avg_nll=17.86 avg_ppl=11.91 speed=5402.37 words/sec time_elapsed=89.28 sec
# epoch 8 (175/272) | step 2080 | avg_nll=17.38 avg_ppl=11.01 speed=5779.84 words/sec time_elapsed=89.68 sec
# epoch 8 (185/272) | step 2090 | avg_nll=16.79 avg_ppl=10.39 speed=6392.55 words/sec time_elapsed=90.04 sec
# epoch 8 (195/272) | step 2100 | avg_nll=17.44 avg_ppl=11.03 speed=6343.26 words/sec time_elapsed=90.41 sec
# Begin validation ...
# validation: step 2100 | dev_ppl=11.872307777404785
# epoch 8 step 2100: save currently the best model to 'model.pt'
# epoch 8 (205/272) | step 2110 | avg_nll=17.27 avg_ppl=10.72 speed=3598.35 words/sec time_elapsed=91.06 sec
# epoch 8 (215/272) | step 2120 | avg_nll=16.89 avg_ppl=10.39 speed=5903.11 words/sec time_elapsed=91.45 sec
# epoch 8 (225/272) | step 2130 | avg_nll=16.93 avg_ppl=10.09 speed=4466.38 words/sec time_elapsed=91.97 sec
# epoch 8 (235/272) | step 2140 | avg_nll=17.03 avg_ppl=10.78 speed=5733.63 words/sec time_elapsed=92.37 sec
# epoch 8 (245/272) | step 2150 | avg_nll=17.57 avg_ppl=11.12 speed=5234.57 words/sec time_elapsed=92.82 sec
# epoch 8 (255/272) | step 2160 | avg_nll=16.56 avg_ppl=10.09 speed=6300.47 words/sec time_elapsed=93.18 sec
# epoch 8 (265/272) | step 2170 | avg_nll=17.34 avg_ppl=10.90 speed=5244.70 words/sec time_elapsed=93.62 sec
# epoch 9 (3/272) | step 2180 | avg_nll=16.37 avg_ppl=9.48 speed=6292.64 words/sec time_elapsed=93.99 sec
# epoch 9 (13/272) | step 2190 | avg_nll=14.90 avg_ppl=8.32 speed=6133.00 words/sec time_elapsed=94.36 sec
# epoch 9 (23/272) | step 2200 | avg_nll=16.14 avg_ppl=9.20 speed=6024.96 words/sec time_elapsed=94.75 sec
# Begin validation ...
# validation: step 2200 | dev_ppl=11.655135154724121
# epoch 9 step 2200: save currently the best model to 'model.pt'
# epoch 9 (33/272) | step 2210 | avg_nll=16.45 avg_ppl=9.98 speed=3887.37 words/sec time_elapsed=95.34 sec
# epoch 9 (43/272) | step 2220 | avg_nll=16.87 avg_ppl=10.27 speed=5933.09 words/sec time_elapsed=95.73 sec
# epoch 9 (53/272) | step 2230 | avg_nll=16.50 avg_ppl=9.77 speed=5848.03 words/sec time_elapsed=96.12 sec
# epoch 9 (63/272) | step 2240 | avg_nll=16.56 avg_ppl=9.88 speed=5699.86 words/sec time_elapsed=96.53 sec
# epoch 9 (73/272) | step 2250 | avg_nll=15.79 avg_ppl=9.35 speed=5633.87 words/sec time_elapsed=96.93 sec
# epoch 9 (83/272) | step 2260 | avg_nll=16.94 avg_ppl=10.34 speed=4931.30 words/sec time_elapsed=97.40 sec
# epoch 9 (93/272) | step 2270 | avg_nll=15.98 avg_ppl=8.86 speed=5909.87 words/sec time_elapsed=97.80 sec
# epoch 9 (103/272) | step 2280 | avg_nll=16.49 avg_ppl=9.93 speed=5916.47 words/sec time_elapsed=98.19 sec
# epoch 9 (113/272) | step 2290 | avg_nll=17.03 avg_ppl=10.34 speed=6060.64 words/sec time_elapsed=98.57 sec
# epoch 9 (123/272) | step 2300 | avg_nll=16.03 avg_ppl=9.10 speed=6428.50 words/sec time_elapsed=98.93 sec
# Begin validation ...
# validation: step 2300 | dev_ppl=11.48303508758545
# epoch 9 step 2300: save currently the best model to 'model.pt'
# epoch 9 (133/272) | step 2310 | avg_nll=16.66 avg_ppl=9.96 speed=4429.81 words/sec time_elapsed=99.46 sec
# epoch 9 (143/272) | step 2320 | avg_nll=16.37 avg_ppl=9.64 speed=6392.50 words/sec time_elapsed=99.82 sec
# epoch 9 (153/272) | step 2330 | avg_nll=16.50 avg_ppl=9.46 speed=5487.73 words/sec time_elapsed=100.25 sec
# epoch 9 (163/272) | step 2340 | avg_nll=16.11 avg_ppl=9.27 speed=6718.26 words/sec time_elapsed=100.59 sec
# epoch 9 (173/272) | step 2350 | avg_nll=16.52 avg_ppl=9.53 speed=6705.90 words/sec time_elapsed=100.94 sec
# epoch 9 (183/272) | step 2360 | avg_nll=15.90 avg_ppl=9.18 speed=6547.97 words/sec time_elapsed=101.29 sec
# epoch 9 (193/272) | step 2370 | avg_nll=16.45 avg_ppl=9.97 speed=6275.82 words/sec time_elapsed=101.66 sec
# epoch 9 (203/272) | step 2380 | avg_nll=16.79 avg_ppl=9.98 speed=6518.10 words/sec time_elapsed=102.01 sec
# epoch 9 (213/272) | step 2390 | avg_nll=15.70 avg_ppl=8.93 speed=6342.09 words/sec time_elapsed=102.38 sec
# epoch 9 (223/272) | step 2400 | avg_nll=17.18 avg_ppl=10.40 speed=6892.21 words/sec time_elapsed=102.72 sec
# Begin validation ...
# validation: step 2400 | dev_ppl=11.069287300109863
# epoch 9 step 2400: save currently the best model to 'model.pt'
# epoch 9 (233/272) | step 2410 | avg_nll=16.19 avg_ppl=9.18 speed=3934.63 words/sec time_elapsed=103.31 sec
# epoch 9 (243/272) | step 2420 | avg_nll=16.82 avg_ppl=9.95 speed=5837.04 words/sec time_elapsed=103.71 sec
# epoch 9 (253/272) | step 2430 | avg_nll=16.32 avg_ppl=9.49 speed=5715.79 words/sec time_elapsed=104.12 sec
# epoch 9 (263/272) | step 2440 | avg_nll=16.90 avg_ppl=10.12 speed=5673.48 words/sec time_elapsed=104.53 sec
# epoch 10 (1/272) | step 2450 | avg_nll=15.60 avg_ppl=8.76 speed=5870.24 words/sec time_elapsed=104.92 sec
# epoch 10 (11/272) | step 2460 | avg_nll=15.84 avg_ppl=9.05 speed=5176.45 words/sec time_elapsed=105.37 sec
# epoch 10 (21/272) | step 2470 | avg_nll=16.37 avg_ppl=9.55 speed=6159.91 words/sec time_elapsed=105.74 sec
# epoch 10 (31/272) | step 2480 | avg_nll=16.07 avg_ppl=9.07 speed=5378.17 words/sec time_elapsed=106.18 sec
# epoch 10 (41/272) | step 2490 | avg_nll=15.71 avg_ppl=8.47 speed=6337.10 words/sec time_elapsed=106.55 sec
# epoch 10 (51/272) | step 2500 | avg_nll=15.89 avg_ppl=9.08 speed=5826.06 words/sec time_elapsed=106.94 sec
# Begin validation ...
# validation: step 2500 | dev_ppl=10.928886413574219
# epoch 10 step 2500: save currently the best model to 'model.pt'
# epoch 10 (61/272) | step 2510 | avg_nll=15.53 avg_ppl=8.76 speed=4067.04 words/sec time_elapsed=107.51 sec
# epoch 10 (71/272) | step 2520 | avg_nll=14.95 avg_ppl=7.96 speed=6010.39 words/sec time_elapsed=107.89 sec
# epoch 10 (81/272) | step 2530 | avg_nll=15.67 avg_ppl=8.68 speed=5462.29 words/sec time_elapsed=108.32 sec
# epoch 10 (91/272) | step 2540 | avg_nll=16.01 avg_ppl=8.95 speed=5364.21 words/sec time_elapsed=108.75 sec
# epoch 10 (101/272) | step 2550 | avg_nll=16.44 avg_ppl=9.47 speed=4856.51 words/sec time_elapsed=109.23 sec
# epoch 10 (111/272) | step 2560 | avg_nll=15.66 avg_ppl=8.44 speed=6035.32 words/sec time_elapsed=109.62 sec
# epoch 10 (121/272) | step 2570 | avg_nll=15.44 avg_ppl=8.33 speed=5988.19 words/sec time_elapsed=110.01 sec
# epoch 10 (131/272) | step 2580 | avg_nll=16.50 avg_ppl=9.99 speed=5947.90 words/sec time_elapsed=110.40 sec
# epoch 10 (141/272) | step 2590 | avg_nll=16.48 avg_ppl=9.29 speed=5713.94 words/sec time_elapsed=110.81 sec
# epoch 10 (151/272) | step 2600 | avg_nll=15.01 avg_ppl=8.00 speed=5161.19 words/sec time_elapsed=111.26 sec
# Begin validation ...
# validation: step 2600 | dev_ppl=10.675365447998047
# epoch 10 step 2600: save currently the best model to 'model.pt'
# epoch 10 (161/272) | step 2610 | avg_nll=15.42 avg_ppl=8.52 speed=3923.01 words/sec time_elapsed=111.85 sec
# epoch 10 (171/272) | step 2620 | avg_nll=15.97 avg_ppl=9.00 speed=5949.52 words/sec time_elapsed=112.24 sec
# epoch 10 (181/272) | step 2630 | avg_nll=15.34 avg_ppl=8.42 speed=5906.82 words/sec time_elapsed=112.63 sec
# epoch 10 (191/272) | step 2640 | avg_nll=15.35 avg_ppl=8.56 speed=6120.48 words/sec time_elapsed=113.00 sec
# epoch 10 (201/272) | step 2650 | avg_nll=15.61 avg_ppl=8.25 speed=6220.69 words/sec time_elapsed=113.38 sec
# epoch 10 (211/272) | step 2660 | avg_nll=15.26 avg_ppl=8.31 speed=5729.17 words/sec time_elapsed=113.78 sec
# epoch 10 (221/272) | step 2670 | avg_nll=14.84 avg_ppl=8.23 speed=5645.53 words/sec time_elapsed=114.18 sec
# epoch 10 (231/272) | step 2680 | avg_nll=16.87 avg_ppl=10.10 speed=5799.36 words/sec time_elapsed=114.59 sec
# epoch 10 (241/272) | step 2690 | avg_nll=15.26 avg_ppl=8.62 speed=5744.29 words/sec time_elapsed=114.98 sec
# epoch 10 (251/272) | step 2700 | avg_nll=15.14 avg_ppl=8.17 speed=5999.79 words/sec time_elapsed=115.37 sec
# Begin validation ...
# validation: step 2700 | dev_ppl=10.483226776123047
# epoch 10 step 2700: save currently the best model to 'model.pt'
# epoch 10 (261/272) | step 2710 | avg_nll=16.76 avg_ppl=9.80 speed=3426.85 words/sec time_elapsed=116.05 sec
# epoch 10 (271/272) | step 2720 | avg_nll=14.83 avg_ppl=7.80 speed=6359.65 words/sec time_elapsed=116.41 sec
# epoch 11 (9/272) | step 2730 | avg_nll=14.27 avg_ppl=7.22 speed=6255.61 words/sec time_elapsed=116.78 sec
# epoch 11 (19/272) | step 2740 | avg_nll=13.86 avg_ppl=7.11 speed=6057.35 words/sec time_elapsed=117.16 sec
# epoch 11 (29/272) | step 2750 | avg_nll=16.43 avg_ppl=9.19 speed=6569.44 words/sec time_elapsed=117.52 sec
# epoch 11 (39/272) | step 2760 | avg_nll=14.79 avg_ppl=7.74 speed=6184.28 words/sec time_elapsed=117.89 sec
# epoch 11 (49/272) | step 2770 | avg_nll=14.74 avg_ppl=7.44 speed=5135.87 words/sec time_elapsed=118.35 sec
# epoch 11 (59/272) | step 2780 | avg_nll=14.82 avg_ppl=7.98 speed=5547.72 words/sec time_elapsed=118.76 sec
# epoch 11 (69/272) | step 2790 | avg_nll=14.73 avg_ppl=7.87 speed=5485.06 words/sec time_elapsed=119.18 sec
# epoch 11 (79/272) | step 2800 | avg_nll=14.12 avg_ppl=7.24 speed=5715.54 words/sec time_elapsed=119.58 sec
# Begin validation ...
# validation: step 2800 | dev_ppl=10.542363166809082
# epoch 11 (89/272) | step 2810 | avg_nll=14.74 avg_ppl=7.76 speed=4041.46 words/sec time_elapsed=120.15 sec
# epoch 11 (99/272) | step 2820 | avg_nll=15.03 avg_ppl=7.75 speed=6526.25 words/sec time_elapsed=120.51 sec
# epoch 11 (109/272) | step 2830 | avg_nll=14.39 avg_ppl=7.40 speed=5710.59 words/sec time_elapsed=120.91 sec
# epoch 11 (119/272) | step 2840 | avg_nll=16.00 avg_ppl=8.82 speed=6343.94 words/sec time_elapsed=121.28 sec
# epoch 11 (129/272) | step 2850 | avg_nll=15.03 avg_ppl=7.94 speed=6208.47 words/sec time_elapsed=121.66 sec
# epoch 11 (139/272) | step 2860 | avg_nll=16.23 avg_ppl=9.22 speed=6057.67 words/sec time_elapsed=122.04 sec
# epoch 11 (149/272) | step 2870 | avg_nll=14.29 avg_ppl=7.36 speed=5542.82 words/sec time_elapsed=122.45 sec
# epoch 11 (159/272) | step 2880 | avg_nll=14.73 avg_ppl=7.71 speed=5377.81 words/sec time_elapsed=122.88 sec
# epoch 11 (169/272) | step 2890 | avg_nll=16.00 avg_ppl=9.07 speed=5500.39 words/sec time_elapsed=123.31 sec
# epoch 11 (179/272) | step 2900 | avg_nll=15.05 avg_ppl=7.94 speed=5492.14 words/sec time_elapsed=123.73 sec
# Begin validation ...
# validation: step 2900 | dev_ppl=10.30811595916748
# epoch 11 step 2900: save currently the best model to 'model.pt'
# epoch 11 (189/272) | step 2910 | avg_nll=14.86 avg_ppl=7.82 speed=3876.24 words/sec time_elapsed=124.33 sec
# epoch 11 (199/272) | step 2920 | avg_nll=15.22 avg_ppl=8.29 speed=6355.96 words/sec time_elapsed=124.69 sec
# epoch 11 (209/272) | step 2930 | avg_nll=15.14 avg_ppl=7.98 speed=6365.37 words/sec time_elapsed=125.05 sec
# epoch 11 (219/272) | step 2940 | avg_nll=15.73 avg_ppl=8.69 speed=6134.52 words/sec time_elapsed=125.43 sec
# epoch 11 (229/272) | step 2950 | avg_nll=16.12 avg_ppl=9.04 speed=6018.22 words/sec time_elapsed=125.82 sec
# epoch 11 (239/272) | step 2960 | avg_nll=15.00 avg_ppl=7.78 speed=6380.92 words/sec time_elapsed=126.19 sec
# epoch 11 (249/272) | step 2970 | avg_nll=15.56 avg_ppl=8.30 speed=5748.87 words/sec time_elapsed=126.60 sec
# epoch 11 (259/272) | step 2980 | avg_nll=14.84 avg_ppl=7.84 speed=5546.02 words/sec time_elapsed=127.02 sec
# epoch 11 (269/272) | step 2990 | avg_nll=14.50 avg_ppl=7.66 speed=5418.37 words/sec time_elapsed=127.44 sec
# epoch 12 (7/272) | step 3000 | avg_nll=14.30 avg_ppl=7.53 speed=5567.08 words/sec time_elapsed=127.84 sec
# Begin validation ...
# validation: step 3000 | dev_ppl=9.992116928100586
# epoch 12 step 3000: save currently the best model to 'model.pt'
# epoch 12 (17/272) | step 3010 | avg_nll=13.99 avg_ppl=7.10 speed=3753.68 words/sec time_elapsed=128.45 sec
# epoch 12 (27/272) | step 3020 | avg_nll=14.29 avg_ppl=7.17 speed=6410.12 words/sec time_elapsed=128.81 sec
# epoch 12 (37/272) | step 3030 | avg_nll=14.82 avg_ppl=8.05 speed=6457.66 words/sec time_elapsed=129.17 sec
# epoch 12 (47/272) | step 3040 | avg_nll=12.98 avg_ppl=6.42 speed=6327.14 words/sec time_elapsed=129.52 sec
# epoch 12 (57/272) | step 3050 | avg_nll=14.80 avg_ppl=7.78 speed=6385.47 words/sec time_elapsed=129.88 sec
# epoch 12 (67/272) | step 3060 | avg_nll=14.49 avg_ppl=7.58 speed=6391.88 words/sec time_elapsed=130.24 sec
# epoch 12 (77/272) | step 3070 | avg_nll=14.20 avg_ppl=7.23 speed=5953.09 words/sec time_elapsed=130.63 sec
# epoch 12 (87/272) | step 3080 | avg_nll=14.27 avg_ppl=6.96 speed=5888.21 words/sec time_elapsed=131.03 sec
# epoch 12 (97/272) | step 3090 | avg_nll=14.26 avg_ppl=7.18 speed=5531.92 words/sec time_elapsed=131.44 sec
# epoch 12 (107/272) | step 3100 | avg_nll=15.69 avg_ppl=8.45 speed=5471.37 words/sec time_elapsed=131.87 sec
# Begin validation ...
# validation: step 3100 | dev_ppl=9.946900367736816
# epoch 12 step 3100: save currently the best model to 'model.pt'
# epoch 12 (117/272) | step 3110 | avg_nll=14.51 avg_ppl=7.41 speed=4013.10 words/sec time_elapsed=132.45 sec
# epoch 12 (127/272) | step 3120 | avg_nll=14.73 avg_ppl=7.46 speed=6609.06 words/sec time_elapsed=132.81 sec
# epoch 12 (137/272) | step 3130 | avg_nll=14.14 avg_ppl=6.72 speed=6721.75 words/sec time_elapsed=133.16 sec
# epoch 12 (147/272) | step 3140 | avg_nll=14.19 avg_ppl=6.99 speed=6380.26 words/sec time_elapsed=133.53 sec
# epoch 12 (157/272) | step 3150 | avg_nll=13.85 avg_ppl=6.79 speed=6433.16 words/sec time_elapsed=133.89 sec
# epoch 12 (167/272) | step 3160 | avg_nll=14.11 avg_ppl=7.01 speed=5734.77 words/sec time_elapsed=134.29 sec
# epoch 12 (177/272) | step 3170 | avg_nll=14.50 avg_ppl=7.11 speed=6095.82 words/sec time_elapsed=134.68 sec
# epoch 12 (187/272) | step 3180 | avg_nll=14.20 avg_ppl=7.16 speed=5819.37 words/sec time_elapsed=135.07 sec
# epoch 12 (197/272) | step 3190 | avg_nll=14.48 avg_ppl=7.38 speed=5858.84 words/sec time_elapsed=135.47 sec
# epoch 12 (207/272) | step 3200 | avg_nll=15.30 avg_ppl=8.02 speed=5697.12 words/sec time_elapsed=135.88 sec
# Begin validation ...
# validation: step 3200 | dev_ppl=9.730427742004395
# epoch 12 step 3200: save currently the best model to 'model.pt'
# epoch 12 (217/272) | step 3210 | avg_nll=14.38 avg_ppl=7.36 speed=3874.02 words/sec time_elapsed=136.48 sec
# epoch 12 (227/272) | step 3220 | avg_nll=15.01 avg_ppl=7.69 speed=5857.17 words/sec time_elapsed=136.88 sec
# epoch 12 (237/272) | step 3230 | avg_nll=15.06 avg_ppl=7.72 speed=5996.12 words/sec time_elapsed=137.27 sec
# epoch 12 (247/272) | step 3240 | avg_nll=14.55 avg_ppl=7.56 speed=5959.99 words/sec time_elapsed=137.66 sec
# epoch 12 (257/272) | step 3250 | avg_nll=14.90 avg_ppl=7.84 speed=5393.12 words/sec time_elapsed=138.09 sec
# epoch 12 (267/272) | step 3260 | avg_nll=14.25 avg_ppl=7.29 speed=5661.29 words/sec time_elapsed=138.49 sec
# epoch 13 (5/272) | step 3270 | avg_nll=13.26 avg_ppl=6.42 speed=5672.44 words/sec time_elapsed=138.90 sec
# epoch 13 (15/272) | step 3280 | avg_nll=14.02 avg_ppl=6.97 speed=5643.70 words/sec time_elapsed=139.31 sec
# epoch 13 (25/272) | step 3290 | avg_nll=13.75 avg_ppl=6.56 speed=5660.97 words/sec time_elapsed=139.72 sec
# epoch 13 (35/272) | step 3300 | avg_nll=13.87 avg_ppl=6.71 speed=5715.02 words/sec time_elapsed=140.13 sec
# Begin validation ...
# validation: step 3300 | dev_ppl=9.597270011901855
# epoch 13 step 3300: save currently the best model to 'model.pt'
# epoch 13 (45/272) | step 3310 | avg_nll=13.82 avg_ppl=6.79 speed=3890.86 words/sec time_elapsed=140.72 sec
# epoch 13 (55/272) | step 3320 | avg_nll=13.12 avg_ppl=6.30 speed=5667.11 words/sec time_elapsed=141.12 sec
# epoch 13 (65/272) | step 3330 | avg_nll=13.79 avg_ppl=6.72 speed=5886.60 words/sec time_elapsed=141.52 sec
# epoch 13 (75/272) | step 3340 | avg_nll=12.61 avg_ppl=5.81 speed=5740.26 words/sec time_elapsed=141.92 sec
# epoch 13 (85/272) | step 3350 | avg_nll=13.07 avg_ppl=6.32 speed=5756.71 words/sec time_elapsed=142.31 sec
# epoch 13 (95/272) | step 3360 | avg_nll=14.36 avg_ppl=7.12 speed=5846.90 words/sec time_elapsed=142.71 sec
# epoch 13 (105/272) | step 3370 | avg_nll=13.47 avg_ppl=6.40 speed=5596.26 words/sec time_elapsed=143.13 sec
# epoch 13 (115/272) | step 3380 | avg_nll=13.37 avg_ppl=6.31 speed=5130.90 words/sec time_elapsed=143.58 sec
# epoch 13 (125/272) | step 3390 | avg_nll=13.56 avg_ppl=6.56 speed=5303.46 words/sec time_elapsed=144.02 sec
# epoch 13 (135/272) | step 3400 | avg_nll=14.15 avg_ppl=7.16 speed=5607.68 words/sec time_elapsed=144.43 sec
# Begin validation ...
# validation: step 3400 | dev_ppl=9.56872844696045
# epoch 13 step 3400: save currently the best model to 'model.pt'
# epoch 13 (145/272) | step 3410 | avg_nll=13.40 avg_ppl=6.53 speed=3469.87 words/sec time_elapsed=145.08 sec
# epoch 13 (155/272) | step 3420 | avg_nll=13.89 avg_ppl=6.94 speed=5184.27 words/sec time_elapsed=145.53 sec
# epoch 13 (165/272) | step 3430 | avg_nll=13.59 avg_ppl=6.60 speed=4701.24 words/sec time_elapsed=146.02 sec
# epoch 13 (175/272) | step 3440 | avg_nll=14.30 avg_ppl=7.15 speed=5305.62 words/sec time_elapsed=146.46 sec
# epoch 13 (185/272) | step 3450 | avg_nll=15.00 avg_ppl=7.85 speed=4973.91 words/sec time_elapsed=146.92 sec
# epoch 13 (195/272) | step 3460 | avg_nll=13.62 avg_ppl=6.80 speed=5500.59 words/sec time_elapsed=147.34 sec
# epoch 13 (205/272) | step 3470 | avg_nll=12.88 avg_ppl=6.04 speed=5638.65 words/sec time_elapsed=147.74 sec
# epoch 13 (215/272) | step 3480 | avg_nll=14.36 avg_ppl=7.06 speed=6131.97 words/sec time_elapsed=148.13 sec
# epoch 13 (225/272) | step 3490 | avg_nll=13.54 avg_ppl=6.45 speed=5754.66 words/sec time_elapsed=148.53 sec
# epoch 13 (235/272) | step 3500 | avg_nll=14.30 avg_ppl=6.76 speed=6141.29 words/sec time_elapsed=148.92 sec
# Begin validation ...
# validation: step 3500 | dev_ppl=9.447169303894043
# epoch 13 step 3500: save currently the best model to 'model.pt'
# epoch 13 (245/272) | step 3510 | avg_nll=14.40 avg_ppl=7.12 speed=4167.15 words/sec time_elapsed=149.48 sec
# epoch 13 (255/272) | step 3520 | avg_nll=14.74 avg_ppl=7.32 speed=6306.38 words/sec time_elapsed=149.86 sec
# epoch 13 (265/272) | step 3530 | avg_nll=14.93 avg_ppl=7.75 speed=6269.58 words/sec time_elapsed=150.23 sec
# epoch 14 (3/272) | step 3540 | avg_nll=13.36 avg_ppl=6.51 speed=6235.65 words/sec time_elapsed=150.60 sec
# epoch 14 (13/272) | step 3550 | avg_nll=14.44 avg_ppl=6.99 speed=6130.03 words/sec time_elapsed=150.99 sec
# epoch 14 (23/272) | step 3560 | avg_nll=12.07 avg_ppl=5.50 speed=5243.02 words/sec time_elapsed=151.42 sec
# epoch 14 (33/272) | step 3570 | avg_nll=13.25 avg_ppl=6.05 speed=5194.95 words/sec time_elapsed=151.87 sec
# epoch 14 (43/272) | step 3580 | avg_nll=12.98 avg_ppl=5.98 speed=5695.95 words/sec time_elapsed=152.28 sec
# epoch 14 (53/272) | step 3590 | avg_nll=13.84 avg_ppl=6.59 speed=6420.94 words/sec time_elapsed=152.65 sec
# epoch 14 (63/272) | step 3600 | avg_nll=12.62 avg_ppl=5.74 speed=6043.66 words/sec time_elapsed=153.03 sec
# Begin validation ...
# validation: step 3600 | dev_ppl=9.29633903503418
# epoch 14 step 3600: save currently the best model to 'model.pt'
# epoch 14 (73/272) | step 3610 | avg_nll=12.79 avg_ppl=5.94 speed=3894.31 words/sec time_elapsed=153.62 sec
# epoch 14 (83/272) | step 3620 | avg_nll=12.15 avg_ppl=5.58 speed=6102.24 words/sec time_elapsed=153.99 sec
# epoch 14 (93/272) | step 3630 | avg_nll=13.02 avg_ppl=5.90 speed=6202.72 words/sec time_elapsed=154.37 sec
# epoch 14 (103/272) | step 3640 | avg_nll=12.98 avg_ppl=6.14 speed=6105.34 words/sec time_elapsed=154.74 sec
# epoch 14 (113/272) | step 3650 | avg_nll=13.23 avg_ppl=6.18 speed=5632.53 words/sec time_elapsed=155.16 sec
# epoch 14 (123/272) | step 3660 | avg_nll=13.52 avg_ppl=6.45 speed=5802.49 words/sec time_elapsed=155.56 sec
# epoch 14 (133/272) | step 3670 | avg_nll=13.81 avg_ppl=6.75 speed=5904.24 words/sec time_elapsed=155.95 sec
# epoch 14 (143/272) | step 3680 | avg_nll=15.05 avg_ppl=7.70 speed=6326.09 words/sec time_elapsed=156.32 sec
# epoch 14 (153/272) | step 3690 | avg_nll=13.69 avg_ppl=6.62 speed=6554.82 words/sec time_elapsed=156.67 sec
# epoch 14 (163/272) | step 3700 | avg_nll=12.72 avg_ppl=5.87 speed=6313.23 words/sec time_elapsed=157.04 sec
# Begin validation ...
# validation: step 3700 | dev_ppl=8.96347427368164
# epoch 14 step 3700: save currently the best model to 'model.pt'
# epoch 14 (173/272) | step 3710 | avg_nll=12.92 avg_ppl=6.00 speed=4281.88 words/sec time_elapsed=157.58 sec
# epoch 14 (183/272) | step 3720 | avg_nll=13.10 avg_ppl=6.06 speed=6172.39 words/sec time_elapsed=157.95 sec
# epoch 14 (193/272) | step 3730 | avg_nll=13.90 avg_ppl=6.75 speed=6354.57 words/sec time_elapsed=158.32 sec
# epoch 14 (203/272) | step 3740 | avg_nll=13.12 avg_ppl=6.27 speed=6290.53 words/sec time_elapsed=158.68 sec
# epoch 14 (213/272) | step 3750 | avg_nll=13.56 avg_ppl=6.42 speed=5842.41 words/sec time_elapsed=159.08 sec
# epoch 14 (223/272) | step 3760 | avg_nll=13.28 avg_ppl=6.25 speed=5766.92 words/sec time_elapsed=159.49 sec
# epoch 14 (233/272) | step 3770 | avg_nll=12.53 avg_ppl=5.76 speed=5729.65 words/sec time_elapsed=159.89 sec
# epoch 14 (243/272) | step 3780 | avg_nll=14.92 avg_ppl=7.47 speed=6257.76 words/sec time_elapsed=160.27 sec
# epoch 14 (253/272) | step 3790 | avg_nll=13.09 avg_ppl=6.25 speed=6397.58 words/sec time_elapsed=160.62 sec
# epoch 14 (263/272) | step 3800 | avg_nll=13.69 avg_ppl=6.42 speed=6629.65 words/sec time_elapsed=160.98 sec
# Begin validation ...
# validation: step 3800 | dev_ppl=9.102497100830078
# epoch 15 (1/272) | step 3810 | avg_nll=12.28 avg_ppl=5.73 speed=4019.74 words/sec time_elapsed=161.54 sec
# epoch 15 (11/272) | step 3820 | avg_nll=12.12 avg_ppl=5.37 speed=6008.59 words/sec time_elapsed=161.92 sec
# epoch 15 (21/272) | step 3830 | avg_nll=11.91 avg_ppl=5.17 speed=6456.77 words/sec time_elapsed=162.28 sec
# epoch 15 (31/272) | step 3840 | avg_nll=11.82 avg_ppl=5.23 speed=6400.63 words/sec time_elapsed=162.64 sec
# epoch 15 (41/272) | step 3850 | avg_nll=12.99 avg_ppl=6.05 speed=6153.90 words/sec time_elapsed=163.01 sec
# epoch 15 (51/272) | step 3860 | avg_nll=12.68 avg_ppl=6.00 speed=5495.05 words/sec time_elapsed=163.43 sec
# epoch 15 (61/272) | step 3870 | avg_nll=12.32 avg_ppl=5.39 speed=5800.02 words/sec time_elapsed=163.83 sec
# epoch 15 (71/272) | step 3880 | avg_nll=12.15 avg_ppl=5.36 speed=6274.45 words/sec time_elapsed=164.20 sec
# epoch 15 (81/272) | step 3890 | avg_nll=11.46 avg_ppl=4.95 speed=5644.20 words/sec time_elapsed=164.61 sec
# epoch 15 (91/272) | step 3900 | avg_nll=13.66 avg_ppl=6.50 speed=6524.06 words/sec time_elapsed=164.96 sec
# Begin validation ...
# validation: step 3900 | dev_ppl=8.932779312133789
# epoch 15 step 3900: save currently the best model to 'model.pt'
# epoch 15 (101/272) | step 3910 | avg_nll=13.20 avg_ppl=6.07 speed=4387.71 words/sec time_elapsed=165.50 sec
# epoch 15 (111/272) | step 3920 | avg_nll=12.87 avg_ppl=6.08 speed=6488.48 words/sec time_elapsed=165.85 sec
# epoch 15 (121/272) | step 3930 | avg_nll=12.40 avg_ppl=5.52 speed=6482.06 words/sec time_elapsed=166.21 sec
# epoch 15 (131/272) | step 3940 | avg_nll=12.95 avg_ppl=5.97 speed=6239.51 words/sec time_elapsed=166.58 sec
# epoch 15 (141/272) | step 3950 | avg_nll=13.08 avg_ppl=5.94 speed=6345.27 words/sec time_elapsed=166.95 sec
# epoch 15 (151/272) | step 3960 | avg_nll=12.38 avg_ppl=5.64 speed=5635.05 words/sec time_elapsed=167.36 sec
# epoch 15 (161/272) | step 3970 | avg_nll=12.36 avg_ppl=5.53 speed=5691.19 words/sec time_elapsed=167.76 sec
# epoch 15 (171/272) | step 3980 | avg_nll=14.05 avg_ppl=6.82 speed=5715.53 words/sec time_elapsed=168.17 sec
# epoch 15 (181/272) | step 3990 | avg_nll=12.33 avg_ppl=5.56 speed=5481.52 words/sec time_elapsed=168.59 sec
# epoch 15 (191/272) | step 4000 | avg_nll=13.78 avg_ppl=6.38 speed=6016.23 words/sec time_elapsed=168.99 sec
# Begin validation ...
# validation: step 4000 | dev_ppl=8.811328887939453
# epoch 15 step 4000: save currently the best model to 'model.pt'
# epoch 15 (201/272) | step 4010 | avg_nll=12.50 avg_ppl=5.67 speed=4095.43 words/sec time_elapsed=169.55 sec
# epoch 15 (211/272) | step 4020 | avg_nll=13.52 avg_ppl=6.34 speed=6662.25 words/sec time_elapsed=169.90 sec
# epoch 15 (221/272) | step 4030 | avg_nll=13.24 avg_ppl=6.21 speed=6573.48 words/sec time_elapsed=170.25 sec
# epoch 15 (231/272) | step 4040 | avg_nll=13.80 avg_ppl=6.68 speed=6375.16 words/sec time_elapsed=170.62 sec
# epoch 15 (241/272) | step 4050 | avg_nll=13.27 avg_ppl=6.03 speed=6274.50 words/sec time_elapsed=171.00 sec
# epoch 15 (251/272) | step 4060 | avg_nll=12.22 avg_ppl=5.48 speed=6083.37 words/sec time_elapsed=171.37 sec
# epoch 15 (261/272) | step 4070 | avg_nll=12.81 avg_ppl=5.85 speed=5908.66 words/sec time_elapsed=171.77 sec
# epoch 15 (271/272) | step 4080 | avg_nll=12.13 avg_ppl=5.56 speed=6040.20 words/sec time_elapsed=172.14 sec
# Reached maximum number of epochs

# %% [markdown]
# ## Evaluate the model
#
# We have trained a seq2seq model for the NMT task. Now let's evaluate the model on the test set by generating translations with beam search and comparing them to the gold translations using the BLEU score.

# %%
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu


def beam_search(
    model: EncoderDecoderModel,
    encoder_input_ids: torch.LongTensor,
    beam_width: int = 5,
    max_len: int = 32,
) -> Tuple[torch.LongTensor, float]:
    """Run beam search on the encoder-decoder model for a single source sequence.

    Args:
        model: The encoder-decoder model.
        encoder_input_ids: The input sequence. Tensor of shape [encoder_sequence_length].
        beam_width: Number of generations to expand at each time step.
        max_len: Stop generation when reaching this length for the generated sequence.

    Returns:
        A tuple (generation, score) where generation is the generated target sequence and
            a tensor of shape [target_sequence_length] and score is the corresponding
            log-probability of this generation.
    """
    model.eval()

    encoder_input_ids = encoder_input_ids.unsqueeze(0)  # Add the batch dimension
    encoder_padding_mask = torch.zeros_like(
        encoder_input_ids, dtype=torch.bool
    )  # No padding
    encoder_outputs = model.forward_encoder(encoder_input_ids, encoder_padding_mask)

    generations = [
        torch.tensor([target_tokenizer.bos_token_id], device=encoder_input_ids.device)
    ]
    scores = [0.0]

    best_generation = None
    best_score = float("-inf")

    for _ in range(max_len):
        new_generations = []
        new_scores = []
        for score, generation in zip(scores, generations):
            generation = generation.unsqueeze(0)  # Add the batch dimension
            padding_mask = torch.zeros_like(generation, dtype=torch.bool)  # No padding
            decoder_output = model.forward_decoder(
                generation, padding_mask, encoder_outputs, encoder_padding_mask
            )
            last_log_probs = decoder_output[0, -1, :].log_softmax(dim=-1)
            top_log_probs, top_indices = last_log_probs.topk(beam_width, dim=-1)

            new_generations.append(
                torch.cat(
                    [generation.expand(beam_width, -1), top_indices[:, None]], dim=1
                )
            )
            new_scores.append(score + top_log_probs)

        new_generations = torch.cat(new_generations, dim=0)
        new_scores = torch.cat(new_scores, dim=0)

        ends_with_eos = target_tokenizer.eos_token_id == new_generations[:, -1]

        if ends_with_eos.any():
            new_completed_generations = new_generations[ends_with_eos]
            new_completed_scores = new_scores[ends_with_eos]

            if new_completed_scores.max() > best_score:
                best_score = new_completed_scores.max()
                best_generation = new_completed_generations[
                    new_completed_scores.argmax()
                ]

        if best_score >= new_scores.max():
            break

        scores, indices = torch.topk(new_scores, beam_width, dim=-1)
        generations = new_generations[indices]

    if best_generation is None:
        best_generation = generations[0]
        best_score = scores[0]

    return best_generation, best_score.cpu().item()


def run_generation(model, test_dataset, beam_size=5, max_decoding_time_step=32):
    """Run beam search decoding on the test set, compute BLEU and return reference and candidate target sentences."""

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("Use device: %s" % device)

    input_sentences = []
    reference_sentences = []
    candidate_sentences = []

    with torch.no_grad():
        for example in tqdm(test_dataset):
            encoder_input_ids = torch.tensor(
                example["encoder_input_ids"], device=device
            )

            generation, _ = beam_search(
                model, encoder_input_ids, beam_size, max_decoding_time_step
            )

            # Decode given source sequence and generated target sequence and avoid special tokens

            input_text = "".join(
                source_tokenizer.decode(token).replace("▁", " ")
                for token in example["encoder_input_ids"][1:-1]
            )
            reference_text = "".join(
                target_tokenizer.decode(token).replace("▁", " ")
                for token in example["decoder_input_ids"][1:-1]
            )
            candidate_text = "".join(
                target_tokenizer.decode(token).replace("▁", " ")
                for token in generation[1:-1].cpu()
            )

            reference_sentences.append(reference_text)
            candidate_sentences.append(candidate_text)
            input_sentences.append(input_text)

    bleu_score = corpus_bleu(
        [[ref] for ref in reference_sentences],
        [candidate for candidate in candidate_sentences],
    )

    return bleu_score, input_sentences, reference_sentences, candidate_sentences

# %%
# Restore the best validation checkpoint
model.load_state_dict(torch.load("model.pt"))

bleu_score, inputs, references, candidates = run_generation(
    model, tokenized_datasets["test"]
)
print("\n\nCorpus BLEU: {}".format(bleu_score * 100))
# Out:
# Use device: cpu
# 100%|██████████| 486/486 [00:33<00:00, 14.67it/s]
# Corpus BLEU: 45.837636771217696

# %% [markdown]
# Let's look at some examples. What do you think of the quality of the translations?

# %%
# Feel free to change the range to look at more samples!
for k in range(10, 20):
    print(f"===== Sample {k} =====")
    print(f"Input: {inputs[k]}")
    print(f"Gold: {references[k]}")
    print(f"Pred: {candidates[k]}")
# Out:
# ===== Sample 10 =====
# Input:  vous me mettez mal a l aise .
# Gold:  you re embarrassing me .
# Pred:  i m looking for out .
# ===== Sample 11 =====
# Input:  c est toi le professeur .
# Gold:  you re the teacher .
# Pred:  you re the teacher .
# ===== Sample 12 =====
# Input:  elle sourit avec bonheur .
# Gold:  she smiled happily .
# Pred:  she is very him of him .
# ===== Sample 13 =====
# Input:  je ne suis pas devin .
# Gold:  i m not a psychic .
# Pred:  i m not wasting .
# ===== Sample 14 =====
# Input:  vous allez perdre .
# Gold:  you re going to lose .
# Pred:  you re going to be .
# ===== Sample 15 =====
# Input:  vous me touchez .
# Gold:  you re touching me .
# Pred:  you re have wise .
# ===== Sample 16 =====
# Input:  je pars aujourd hui .
# Gold:  i m leaving today .
# Pred:  i m happy .
# ===== Sample 17 =====
# Input:  je ne suis pas une sainte .
# Gold:  i m no saint .
# Pred:  i m not a .
# ===== Sample 18 =====
# Input:  je suis puissant .
# Gold:  i m powerful .
# Pred:  i m invited .
# ===== Sample 19 =====
# Input:  vous n etes qu un lache .
# Gold:  you re nothing but a coward .
# Pred:  you re not a working .

# %% [markdown]
# # Questions
#
# Please answer written questions from the assignment in this section. You can alter the provided code to obtain the answers, but be careful not to break anything!
# ---
# **(b) (4 points)**
#
# **(i) What vocabulary size are we using for the source and target language?**
# **Ans:** <span style="color:green;">*3200*</span>
#
# ---
# **(ii) Approximately how many source and target tokens are on average contained in a training batch? What proportion of these tokens are `<pad>` tokens on average?**
# **Ans:** <span style="color:green;">*Batch Size * Max Length*</span>
#
# ---
# **(iii) What is the specific purpose of saving the model parameters in a file `model.pt` throughout training in the code we provide?**
# **Ans:**
# - <span style="color:green;">It allows for **checkpointing**, so training can be resumed if interrupted. It facilitates evaluation and testing by enabling the model to be reloaded without retraining. The saved model can be used for deployment in real-world applications like machine translation. It ensures reproducibility, allowing experiments to be repeated and validated later. Additionally, it supports *fine-tuning*, enabling the model to continue training or be adjusted with new data.</span>
#
# ---
#
# **(c) (2 points)**
#
# **Manually look at some results and compare them with the gold answers. What do you think of the quality of the translations? Are these grammatical English sentences? Can you identify any common mistakes?**
#
# **Ans:**
# - <span style="color:green;">The quality of the translations is generally poor, with many inaccuracies and grammatical errors.
# For instance, in Sample 10:Input: "vous me mettez mal a l aise." Gold: "you're embarrassing me."Predicted: "i'm looking for out."
# The predicted translation is incorrect and nonsensical. Common mistakes include incorrect word choices (e.g., in Sample 18: "je suis puissant." translated as "i'm invited." instead of "i'm powerful"), incomplete sentences (e.g., in Sample 17: "je ne suis pas une sainte." translated as "i'm not a."), and misinterpretations leading to ungrammatical English. Only a few translations, like Sample 11 ("c est toi le professeur." translated correctly as "you're the teacher."), are accurate. Overall, the model frequently fails to produce reliable and coherent English sentences from the French inputs. </span>
#
# ---
# **(d) (4 points)**
#
# **Consider the provided beam search method. This implementation is not efficient and performs a lot of repeated computation. Identify the issue and propose how you can fix it. In particular, describe how would you have to change the arguments and return values of your EncoderDecoderModel and its sub-modules?**
#
# **Ans:** <span style="color:green;">The beam search method is inefficient due to redundant recomputations of decoder states at every step. This can be addressed through the following improvements:</span>
# - <span style="color:green;">**Caching Partial Computations:** Store decoder states (e.g., hidden or attention states) after each token generation and reuse them for the next step.</span>
# - <span style="color:green;">**Batch Processing:** Process all beams in parallel at each step, leveraging batch processing to reduce computation time.</span>
# - <span style="color:green;">**Early Stopping:** Stop expanding beams immediately after generating an end-of-sequence (EOS) token.</span>
# - <span style="color:green;">**Efficient State Passing:** Modify the decoder and model to return and accept cached states (e.g., past key-value pairs for transformers), ensuring computations are reused without redundant recalculations.</span>
